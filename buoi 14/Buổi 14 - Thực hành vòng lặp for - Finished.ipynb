# %% [markdown]
# #  Thực hành vòng lặp for
#
# ### Bài 1
#
# Nhập vào một số số, in ra bảng cửa chương của số đó

# %%
so = int(input("Nhập vào số:"))
for i in range(1,11):
    print(so,"x",i,"=",so*i)
# Out:
# Nhập vào số:3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# ### Bài 2
#
# Nhập vào một câu nói (mỗi từ cách nhau một khoảng trắng, không có dấu phẩy, chấm), hãy tách từng từ trong chuỗi ra rồi in lên màn hình. Mỗi từ in kèm với độ dài cửa từ đó
#
# Ví dụ:
#
# Nhập: Xin chào
#
# In:
#
# Xin 3
#
# Chào 4

# %%
## split???? Liên quan đến List
## Không sử dụng những câu lệnh có sẵn chẳng hạn như: find, count,...
chuoi = input("Nhập vào chuỗi:")
chuoi_luu = ""
for i in chuoi:
    if i != " ":
        chuoi_luu += i
    else:
        print(chuoi_luu,len(chuoi_luu))
        chuoi_luu = ""
print(chuoi_luu,len(chuoi_luu))
# Out:
# Nhập vào chuỗi:xin chào các bạn
# xin 3
# chào 4
# các 3
# bạn 3

# %%
chuoi = input("Nhập vào chuỗi:")
chuoi_luu = ""
k = 0
for i in range(len(chuoi)):
    if (chuoi[i] == " "):
        print(chuoi[k:i],i-k)
        k = i + 1
print(chuoi[k:i+1],i-k+1)
# Out:
# Nhập vào chuỗi:xin chào
# xin 3
# chào 4

# %% [markdown]
# ### Bài 3
#
# Nhập vào một chuỗi có 2 số nguyên, mỗi số cách nhau một dấu phẩy, hãy tính tổng của hai số đó
#
# Ví dụ:
#
# Nhập: 2,3
# In: 5

# %%
## Không dùng lệnh find, count, split
chuoi = input("Nhập vào chuỗi:")
for i in range(len(chuoi)):
    if chuoi[i] == ",":
        sodau = chuoi[:i]
        sosau = chuoi[i+1:]
        break
tong = int(sodau) + int(sosau)
print(tong)
# Out:
# Nhập vào chuỗi:147,708
# 855

# %% [markdown]
# ### Bài 4
#
# Nhập vào một chuỗi, hãy tách toàn bộ số trong chuỗi và tính tổng của chuỗi đó (chuỗi chỉ có số nguyên dương)

# %%
## sads237fjkd16fjklad17slakjd18
## 237 + 16 + 17 + 18 = 288
chuoi = input("Nhập vào chuỗi:")
chuoi += "a"
luutru = ""
tong = 0
for i in chuoi:
    if i.isnumeric():
        luutru += i
    else:
        if luutru != "":
            tong += int(luutru)
            luutru = ""
print(tong)
# Out:
# Nhập vào chuỗi:sads237fjkd16fjklad17slakjd18
# 288

# %% [markdown]
# ### Bài 5
#
# Nhập vào chuỗi không giới hạn được tạo bởi 3 keywords: tròn, vuông, tam giác (mỗi một keyworks cách nhau một dấu phẩy)
#
# Nhập vào a (nhập a từ 50 - 100)
#
# Hãy vẽ các hình đã nhập dựa theo kích thước a (đối với tam giác (tam giác đều) và vuông là cạnh, đối với hình tròn là đường kính)
#
# Cho kích cỡ màn hình là (1000,a+50), canh chỉnh sao cho hình được vẽ bắt đầu từ trên xuống, mỗi hình cách nhau 20 đơn vị
#
# VD:
#
# Mời nhập chuỗi:tròn,vuông,tam giác,tròn,vuông
#
# Mời nhập a:50
#
# Vẽ:
#
# ![image-2.png](attachment:image-2.png)

# %%
s = input('Nhập chuỗi: ')
a = int(input('Nhập một số từ 50 đến 100: '))
s += ","
luu = ""
for i in s:
    if i != ",": ## khi i khác , thì ta đưa i vào biến lưu
        luu += i
    else: ## khi i bằng ,
        print(luu)
        luu = ""
# Out:
# Nhập chuỗi: tròn,vuông,tam giác,tròn,vuông
# Nhập một số từ 50 đến 100: 756
# tròn
# vuông
# tam giác
# tròn
# vuông

# %% [markdown]
# ### Bài 6
#
# Cần có tổng 200.000đ từ 3 loại giấy bạc 1000đ, 2000đ, và 5000đ. Lập
# chương tình để tìm tất cả các phương án có thể.

# %%
for i in range(0,201):
    for j in range(0,101):
        k = (200000 - 1000*i - 2000*j)/5000 ## có những trường mình sẽ chia ra k không phải là số nguyên
        if int(k) == k and k >= 0: ## kiểm tra k có phải là số nguyên không, k không được phép âm
            print("1000 x",i,"+ 2000 x",j,"+ 5000 x",int(k))
# Out:
# 1000 x 0 + 2000 x 0 + 5000 x 40
# 1000 x 0 + 2000 x 5 + 5000 x 38
# 1000 x 0 + 2000 x 10 + 5000 x 36
# 1000 x 0 + 2000 x 15 + 5000 x 34
# 1000 x 0 + 2000 x 20 + 5000 x 32
# 1000 x 0 + 2000 x 25 + 5000 x 30
# 1000 x 0 + 2000 x 30 + 5000 x 28
# 1000 x 0 + 2000 x 35 + 5000 x 26
# 1000 x 0 + 2000 x 40 + 5000 x 24
# 1000 x 0 + 2000 x 45 + 5000 x 22
# 1000 x 0 + 2000 x 50 + 5000 x 20
# 1000 x 0 + 2000 x 55 + 5000 x 18
# 1000 x 0 + 2000 x 60 + 5000 x 16
# 1000 x 0 + 2000 x 65 + 5000 x 14
# 1000 x 0 + 2000 x 70 + 5000 x 12
# 1000 x 0 + 2000 x 75 + 5000 x 10
# 1000 x 0 + 2000 x 80 + 5000 x 8
# 1000 x 0 + 2000 x 85 + 5000 x 6
# 1000 x 0 + 2000 x 90 + 5000 x 4
# 1000 x 0 + 2000 x 95 + 5000 x 2
# 1000 x 0 + 2000 x 100 + 5000 x 0
# 1000 x 1 + 2000 x 2 + 5000 x 39
# 1000 x 1 + 2000 x 7 + 5000 x 37
# 1000 x 1 + 2000 x 12 + 5000 x 35
# 1000 x 1 + 2000 x 17 + 5000 x 33
# 1000 x 1 + 2000 x 22 + 5000 x 31
# 1000 x 1 + 2000 x 27 + 5000 x 29
# 1000 x 1 + 2000 x 32 + 5000 x 27
# 1000 x 1 + 2000 x 37 + 5000 x 25
# 1000 x 1 + 2000 x 42 + 5000 x 23
# 1000 x 1 + 2000 x 47 + 5000 x 21
# 1000 x 1 + 2000 x 52 + 5000 x 19
# 1000 x 1 + 2000 x 57 + 5000 x 17
# 1000 x 1 + 2000 x 62 + 5000 x 15
# 1000 x 1 + 2000 x 67 + 5000 x 13
# 1000 x 1 + 2000 x 72 + 5000 x 11
# 1000 x 1 + 2000 x 77 + 5000 x 9
# 1000 x 1 + 2000 x 82 + 5000 x 7
# 1000 x 1 + 2000 x 87 + 5000 x 5
# 1000 x 1 + 2000 x 92 + 5000 x 3
# 1000 x 1 + 2000 x 97 + 5000 x 1
# 1000 x 2 + 2000 x 4 + 5000 x 38
# 1000 x 2 + 2000 x 9 + 5000 x 36
# 1000 x 2 + 2000 x 14 + 5000 x 34
# 1000 x 2 + 2000 x 19 + 5000 x 32
# 1000 x 2 + 2000 x 24 + 5000 x 30
# 1000 x 2 + 2000 x 29 + 5000 x 28
# 1000 x 2 + 2000 x 34 + 5000 x 26
# 1000 x 2 + 2000 x 39 + 5000 x 24
# 1000 x 2 + 2000 x 44 + 5000 x 22
# 1000 x 2 + 2000 x 49 + 5000 x 20
# 1000 x 2 + 2000 x 54 + 5000 x 18
# 1000 x 2 + 2000 x 59 + 5000 x 16
# 1000 x 2 + 2000 x 64 + 5000 x 14
# 1000 x 2 + 2000 x 69 + 5000 x 12
# 1000 x 2 + 2000 x 74 + 5000 x 10
# 1000 x 2 + 2000 x 79 + 5000 x 8
# 1000 x 2 + 2000 x 84 + 5000 x 6
# 1000 x 2 + 2000 x 89 + 5000 x 4
# 1000 x 2 + 2000 x 94 + 5000 x 2
# 1000 x 2 + 2000 x 99 + 5000 x 0
# 1000 x 3 + 2000 x 1 + 5000 x 39
# 1000 x 3 + 2000 x 6 + 5000 x 37
# 1000 x 3 + 2000 x 11 + 5000 x 35
# 1000 x 3 + 2000 x 16 + 5000 x 33
# 1000 x 3 + 2000 x 21 + 5000 x 31
# 1000 x 3 + 2000 x 26 + 5000 x 29
# 1000 x 3 + 2000 x 31 + 5000 x 27
# 1000 x 3 + 2000 x 36 + 5000 x 25
# 1000 x 3 + 2000 x 41 + 5000 x 23
# 1000 x 3 + 2000 x 46 + 5000 x 21
# 1000 x 3 + 2000 x 51 + 5000 x 19
# 1000 x 3 + 2000 x 56 + 5000 x 17
# 1000 x 3 + 2000 x 61 + 5000 x 15
# 1000 x 3 + 2000 x 66 + 5000 x 13
# 1000 x 3 + 2000 x 71 + 5000 x 11
# 1000 x 3 + 2000 x 76 + 5000 x 9
# 1000 x 3 + 2000 x 81 + 5000 x 7
# 1000 x 3 + 2000 x 86 + 5000 x 5
# 1000 x 3 + 2000 x 91 + 5000 x 3
# 1000 x 3 + 2000 x 96 + 5000 x 1
# 1000 x 4 + 2000 x 3 + 5000 x 38
# 1000 x 4 + 2000 x 8 + 5000 x 36
# 1000 x 4 + 2000 x 13 + 5000 x 34
# 1000 x 4 + 2000 x 18 + 5000 x 32
# 1000 x 4 + 2000 x 23 + 5000 x 30
# 1000 x 4 + 2000 x 28 + 5000 x 28
# 1000 x 4 + 2000 x 33 + 5000 x 26
# 1000 x 4 + 2000 x 38 + 5000 x 24
# 1000 x 4 + 2000 x 43 + 5000 x 22
# 1000 x 4 + 2000 x 48 + 5000 x 20
# 1000 x 4 + 2000 x 53 + 5000 x 18
# 1000 x 4 + 2000 x 58 + 5000 x 16
# 1000 x 4 + 2000 x 63 + 5000 x 14
# 1000 x 4 + 2000 x 68 + 5000 x 12
# 1000 x 4 + 2000 x 73 + 5000 x 10
# 1000 x 4 + 2000 x 78 + 5000 x 8
# 1000 x 4 + 2000 x 83 + 5000 x 6
# 1000 x 4 + 2000 x 88 + 5000 x 4
# 1000 x 4 + 2000 x 93 + 5000 x 2
# 1000 x 4 + 2000 x 98 + 5000 x 0
# 1000 x 5 + 2000 x 0 + 5000 x 39
# 1000 x 5 + 2000 x 5 + 5000 x 37
# 1000 x 5 + 2000 x 10 + 5000 x 35
# 1000 x 5 + 2000 x 15 + 5000 x 33
# 1000 x 5 + 2000 x 20 + 5000 x 31
# 1000 x 5 + 2000 x 25 + 5000 x 29
# 1000 x 5 + 2000 x 30 + 5000 x 27
# 1000 x 5 + 2000 x 35 + 5000 x 25
# 1000 x 5 + 2000 x 40 + 5000 x 23
# 1000 x 5 + 2000 x 45 + 5000 x 21
# 1000 x 5 + 2000 x 50 + 5000 x 19
# 1000 x 5 + 2000 x 55 + 5000 x 17
# 1000 x 5 + 2000 x 60 + 5000 x 15
# 1000 x 5 + 2000 x 65 + 5000 x 13
# 1000 x 5 + 2000 x 70 + 5000 x 11
# 1000 x 5 + 2000 x 75 + 5000 x 9
# 1000 x 5 + 2000 x 80 + 5000 x 7
# 1000 x 5 + 2000 x 85 + 5000 x 5
# 1000 x 5 + 2000 x 90 + 5000 x 3
# 1000 x 5 + 2000 x 95 + 5000 x 1
# 1000 x 6 + 2000 x 2 + 5000 x 38
# 1000 x 6 + 2000 x 7 + 5000 x 36
# 1000 x 6 + 2000 x 12 + 5000 x 34
# 1000 x 6 + 2000 x 17 + 5000 x 32
# 1000 x 6 + 2000 x 22 + 5000 x 30
# 1000 x 6 + 2000 x 27 + 5000 x 28
# 1000 x 6 + 2000 x 32 + 5000 x 26
# 1000 x 6 + 2000 x 37 + 5000 x 24
# 1000 x 6 + 2000 x 42 + 5000 x 22
# 1000 x 6 + 2000 x 47 + 5000 x 20
# 1000 x 6 + 2000 x 52 + 5000 x 18
# 1000 x 6 + 2000 x 57 + 5000 x 16
# 1000 x 6 + 2000 x 62 + 5000 x 14
# 1000 x 6 + 2000 x 67 + 5000 x 12
# 1000 x 6 + 2000 x 72 + 5000 x 10
# 1000 x 6 + 2000 x 77 + 5000 x 8
# 1000 x 6 + 2000 x 82 + 5000 x 6
# 1000 x 6 + 2000 x 87 + 5000 x 4
# 1000 x 6 + 2000 x 92 + 5000 x 2
# 1000 x 6 + 2000 x 97 + 5000 x 0
# 1000 x 7 + 2000 x 4 + 5000 x 37
# 1000 x 7 + 2000 x 9 + 5000 x 35
# 1000 x 7 + 2000 x 14 + 5000 x 33
# 1000 x 7 + 2000 x 19 + 5000 x 31
# 1000 x 7 + 2000 x 24 + 5000 x 29
# 1000 x 7 + 2000 x 29 + 5000 x 27
# 1000 x 7 + 2000 x 34 + 5000 x 25
# 1000 x 7 + 2000 x 39 + 5000 x 23
# 1000 x 7 + 2000 x 44 + 5000 x 21
# 1000 x 7 + 2000 x 49 + 5000 x 19
# 1000 x 7 + 2000 x 54 + 5000 x 17
# 1000 x 7 + 2000 x 59 + 5000 x 15
# 1000 x 7 + 2000 x 64 + 5000 x 13
# 1000 x 7 + 2000 x 69 + 5000 x 11
# 1000 x 7 + 2000 x 74 + 5000 x 9
# 1000 x 7 + 2000 x 79 + 5000 x 7
# 1000 x 7 + 2000 x 84 + 5000 x 5
# 1000 x 7 + 2000 x 89 + 5000 x 3
# 1000 x 7 + 2000 x 94 + 5000 x 1
# 1000 x 8 + 2000 x 1 + 5000 x 38
# 1000 x 8 + 2000 x 6 + 5000 x 36
# 1000 x 8 + 2000 x 11 + 5000 x 34
# 1000 x 8 + 2000 x 16 + 5000 x 32
# 1000 x 8 + 2000 x 21 + 5000 x 30
# 1000 x 8 + 2000 x 26 + 5000 x 28
# 1000 x 8 + 2000 x 31 + 5000 x 26
# 1000 x 8 + 2000 x 36 + 5000 x 24
# 1000 x 8 + 2000 x 41 + 5000 x 22
# 1000 x 8 + 2000 x 46 + 5000 x 20
# 1000 x 8 + 2000 x 51 + 5000 x 18
# 1000 x 8 + 2000 x 56 + 5000 x 16
# 1000 x 8 + 2000 x 61 + 5000 x 14
# 1000 x 8 + 2000 x 66 + 5000 x 12
# 1000 x 8 + 2000 x 71 + 5000 x 10
# 1000 x 8 + 2000 x 76 + 5000 x 8
# 1000 x 8 + 2000 x 81 + 5000 x 6
# 1000 x 8 + 2000 x 86 + 5000 x 4
# 1000 x 8 + 2000 x 91 + 5000 x 2
# 1000 x 8 + 2000 x 96 + 5000 x 0
# 1000 x 9 + 2000 x 3 + 5000 x 37
# 1000 x 9 + 2000 x 8 + 5000 x 35
# 1000 x 9 + 2000 x 13 + 5000 x 33
# 1000 x 9 + 2000 x 18 + 5000 x 31
# 1000 x 9 + 2000 x 23 + 5000 x 29
# 1000 x 9 + 2000 x 28 + 5000 x 27
# 1000 x 9 + 2000 x 33 + 5000 x 25
# 1000 x 9 + 2000 x 38 + 5000 x 23
# 1000 x 9 + 2000 x 43 + 5000 x 21
# 1000 x 9 + 2000 x 48 + 5000 x 19
# 1000 x 9 + 2000 x 53 + 5000 x 17
# 1000 x 9 + 2000 x 58 + 5000 x 15
# 1000 x 9 + 2000 x 63 + 5000 x 13
# 1000 x 9 + 2000 x 68 + 5000 x 11
# 1000 x 9 + 2000 x 73 + 5000 x 9
# 1000 x 9 + 2000 x 78 + 5000 x 7
# 1000 x 9 + 2000 x 83 + 5000 x 5
# 1000 x 9 + 2000 x 88 + 5000 x 3
# 1000 x 9 + 2000 x 93 + 5000 x 1
# 1000 x 10 + 2000 x 0 + 5000 x 38
# 1000 x 10 + 2000 x 5 + 5000 x 36
# 1000 x 10 + 2000 x 10 + 5000 x 34
# 1000 x 10 + 2000 x 15 + 5000 x 32
# 1000 x 10 + 2000 x 20 + 5000 x 30
# 1000 x 10 + 2000 x 25 + 5000 x 28
# 1000 x 10 + 2000 x 30 + 5000 x 26
# 1000 x 10 + 2000 x 35 + 5000 x 24
# 1000 x 10 + 2000 x 40 + 5000 x 22
# 1000 x 10 + 2000 x 45 + 5000 x 20
# 1000 x 10 + 2000 x 50 + 5000 x 18
# 1000 x 10 + 2000 x 55 + 5000 x 16
# 1000 x 10 + 2000 x 60 + 5000 x 14
# 1000 x 10 + 2000 x 65 + 5000 x 12
# 1000 x 10 + 2000 x 70 + 5000 x 10
# 1000 x 10 + 2000 x 75 + 5000 x 8
# 1000 x 10 + 2000 x 80 + 5000 x 6
# 1000 x 10 + 2000 x 85 + 5000 x 4
# 1000 x 10 + 2000 x 90 + 5000 x 2
# 1000 x 10 + 2000 x 95 + 5000 x 0
# 1000 x 11 + 2000 x 2 + 5000 x 37
# 1000 x 11 + 2000 x 7 + 5000 x 35
# 1000 x 11 + 2000 x 12 + 5000 x 33
# 1000 x 11 + 2000 x 17 + 5000 x 31
# 1000 x 11 + 2000 x 22 + 5000 x 29
# 1000 x 11 + 2000 x 27 + 5000 x 27
# 1000 x 11 + 2000 x 32 + 5000 x 25
# 1000 x 11 + 2000 x 37 + 5000 x 23
# 1000 x 11 + 2000 x 42 + 5000 x 21
# 1000 x 11 + 2000 x 47 + 5000 x 19
# 1000 x 11 + 2000 x 52 + 5000 x 17
# 1000 x 11 + 2000 x 57 + 5000 x 15
# 1000 x 11 + 2000 x 62 + 5000 x 13
# 1000 x 11 + 2000 x 67 + 5000 x 11
# 1000 x 11 + 2000 x 72 + 5000 x 9
# 1000 x 11 + 2000 x 77 + 5000 x 7
# 1000 x 11 + 2000 x 82 + 5000 x 5
# 1000 x 11 + 2000 x 87 + 5000 x 3
# 1000 x 11 + 2000 x 92 + 5000 x 1
# 1000 x 12 + 2000 x 4 + 5000 x 36
# 1000 x 12 + 2000 x 9 + 5000 x 34
# 1000 x 12 + 2000 x 14 + 5000 x 32
# 1000 x 12 + 2000 x 19 + 5000 x 30
# 1000 x 12 + 2000 x 24 + 5000 x 28
# 1000 x 12 + 2000 x 29 + 5000 x 26
# 1000 x 12 + 2000 x 34 + 5000 x 24
# 1000 x 12 + 2000 x 39 + 5000 x 22
# 1000 x 12 + 2000 x 44 + 5000 x 20
# 1000 x 12 + 2000 x 49 + 5000 x 18
# 1000 x 12 + 2000 x 54 + 5000 x 16
# 1000 x 12 + 2000 x 59 + 5000 x 14
# 1000 x 12 + 2000 x 64 + 5000 x 12
# 1000 x 12 + 2000 x 69 + 5000 x 10
# 1000 x 12 + 2000 x 74 + 5000 x 8
# 1000 x 12 + 2000 x 79 + 5000 x 6
# 1000 x 12 + 2000 x 84 + 5000 x 4
# 1000 x 12 + 2000 x 89 + 5000 x 2
# 1000 x 12 + 2000 x 94 + 5000 x 0
# 1000 x 13 + 2000 x 1 + 5000 x 37
# 1000 x 13 + 2000 x 6 + 5000 x 35
# 1000 x 13 + 2000 x 11 + 5000 x 33
# 1000 x 13 + 2000 x 16 + 5000 x 31
# 1000 x 13 + 2000 x 21 + 5000 x 29
# 1000 x 13 + 2000 x 26 + 5000 x 27
# 1000 x 13 + 2000 x 31 + 5000 x 25
# 1000 x 13 + 2000 x 36 + 5000 x 23
# 1000 x 13 + 2000 x 41 + 5000 x 21
# 1000 x 13 + 2000 x 46 + 5000 x 19
# 1000 x 13 + 2000 x 51 + 5000 x 17
# 1000 x 13 + 2000 x 56 + 5000 x 15
# 1000 x 13 + 2000 x 61 + 5000 x 13
# 1000 x 13 + 2000 x 66 + 5000 x 11
# 1000 x 13 + 2000 x 71 + 5000 x 9
# 1000 x 13 + 2000 x 76 + 5000 x 7
# 1000 x 13 + 2000 x 81 + 5000 x 5
# 1000 x 13 + 2000 x 86 + 5000 x 3
# 1000 x 13 + 2000 x 91 + 5000 x 1
# 1000 x 14 + 2000 x 3 + 5000 x 36
# 1000 x 14 + 2000 x 8 + 5000 x 34
# 1000 x 14 + 2000 x 13 + 5000 x 32
# 1000 x 14 + 2000 x 18 + 5000 x 30
# 1000 x 14 + 2000 x 23 + 5000 x 28
# 1000 x 14 + 2000 x 28 + 5000 x 26
# 1000 x 14 + 2000 x 33 + 5000 x 24
# 1000 x 14 + 2000 x 38 + 5000 x 22
# 1000 x 14 + 2000 x 43 + 5000 x 20
# 1000 x 14 + 2000 x 48 + 5000 x 18
# 1000 x 14 + 2000 x 53 + 5000 x 16
# 1000 x 14 + 2000 x 58 + 5000 x 14
# 1000 x 14 + 2000 x 63 + 5000 x 12
# 1000 x 14 + 2000 x 68 + 5000 x 10
# 1000 x 14 + 2000 x 73 + 5000 x 8
# 1000 x 14 + 2000 x 78 + 5000 x 6
# 1000 x 14 + 2000 x 83 + 5000 x 4
# 1000 x 14 + 2000 x 88 + 5000 x 2
# 1000 x 14 + 2000 x 93 + 5000 x 0
# 1000 x 15 + 2000 x 0 + 5000 x 37
# 1000 x 15 + 2000 x 5 + 5000 x 35
# 1000 x 15 + 2000 x 10 + 5000 x 33
# 1000 x 15 + 2000 x 15 + 5000 x 31
# 1000 x 15 + 2000 x 20 + 5000 x 29
# 1000 x 15 + 2000 x 25 + 5000 x 27
# 1000 x 15 + 2000 x 30 + 5000 x 25
# 1000 x 15 + 2000 x 35 + 5000 x 23
# 1000 x 15 + 2000 x 40 + 5000 x 21
# 1000 x 15 + 2000 x 45 + 5000 x 19
# 1000 x 15 + 2000 x 50 + 5000 x 17
# 1000 x 15 + 2000 x 55 + 5000 x 15
# 1000 x 15 + 2000 x 60 + 5000 x 13
# 1000 x 15 + 2000 x 65 + 5000 x 11
# 1000 x 15 + 2000 x 70 + 5000 x 9
# 1000 x 15 + 2000 x 75 + 5000 x 7
# 1000 x 15 + 2000 x 80 + 5000 x 5
# 1000 x 15 + 2000 x 85 + 5000 x 3
# 1000 x 15 + 2000 x 90 + 5000 x 1
# 1000 x 16 + 2000 x 2 + 5000 x 36
# 1000 x 16 + 2000 x 7 + 5000 x 34
# 1000 x 16 + 2000 x 12 + 5000 x 32
# 1000 x 16 + 2000 x 17 + 5000 x 30
# 1000 x 16 + 2000 x 22 + 5000 x 28
# 1000 x 16 + 2000 x 27 + 5000 x 26
# 1000 x 16 + 2000 x 32 + 5000 x 24
# 1000 x 16 + 2000 x 37 + 5000 x 22
# 1000 x 16 + 2000 x 42 + 5000 x 20
# 1000 x 16 + 2000 x 47 + 5000 x 18
# 1000 x 16 + 2000 x 52 + 5000 x 16
# 1000 x 16 + 2000 x 57 + 5000 x 14
# 1000 x 16 + 2000 x 62 + 5000 x 12
# 1000 x 16 + 2000 x 67 + 5000 x 10
# 1000 x 16 + 2000 x 72 + 5000 x 8
# 1000 x 16 + 2000 x 77 + 5000 x 6
# 1000 x 16 + 2000 x 82 + 5000 x 4
# 1000 x 16 + 2000 x 87 + 5000 x 2
# 1000 x 16 + 2000 x 92 + 5000 x 0
# 1000 x 17 + 2000 x 4 + 5000 x 35
# 1000 x 17 + 2000 x 9 + 5000 x 33
# 1000 x 17 + 2000 x 14 + 5000 x 31
# 1000 x 17 + 2000 x 19 + 5000 x 29
# 1000 x 17 + 2000 x 24 + 5000 x 27
# 1000 x 17 + 2000 x 29 + 5000 x 25
# 1000 x 17 + 2000 x 34 + 5000 x 23
# 1000 x 17 + 2000 x 39 + 5000 x 21
# 1000 x 17 + 2000 x 44 + 5000 x 19
# 1000 x 17 + 2000 x 49 + 5000 x 17
# 1000 x 17 + 2000 x 54 + 5000 x 15
# 1000 x 17 + 2000 x 59 + 5000 x 13
# 1000 x 17 + 2000 x 64 + 5000 x 11
# 1000 x 17 + 2000 x 69 + 5000 x 9
# 1000 x 17 + 2000 x 74 + 5000 x 7
# 1000 x 17 + 2000 x 79 + 5000 x 5
# 1000 x 17 + 2000 x 84 + 5000 x 3
# 1000 x 17 + 2000 x 89 + 5000 x 1
# 1000 x 18 + 2000 x 1 + 5000 x 36
# 1000 x 18 + 2000 x 6 + 5000 x 34
# 1000 x 18 + 2000 x 11 + 5000 x 32
# 1000 x 18 + 2000 x 16 + 5000 x 30
# 1000 x 18 + 2000 x 21 + 5000 x 28
# 1000 x 18 + 2000 x 26 + 5000 x 26
# 1000 x 18 + 2000 x 31 + 5000 x 24
# 1000 x 18 + 2000 x 36 + 5000 x 22
# 1000 x 18 + 2000 x 41 + 5000 x 20
# 1000 x 18 + 2000 x 46 + 5000 x 18
# 1000 x 18 + 2000 x 51 + 5000 x 16
# 1000 x 18 + 2000 x 56 + 5000 x 14
# 1000 x 18 + 2000 x 61 + 5000 x 12
# 1000 x 18 + 2000 x 66 + 5000 x 10
# 1000 x 18 + 2000 x 71 + 5000 x 8
# 1000 x 18 + 2000 x 76 + 5000 x 6
# 1000 x 18 + 2000 x 81 + 5000 x 4
# 1000 x 18 + 2000 x 86 + 5000 x 2
# 1000 x 18 + 2000 x 91 + 5000 x 0
# 1000 x 19 + 2000 x 3 + 5000 x 35
# 1000 x 19 + 2000 x 8 + 5000 x 33
# 1000 x 19 + 2000 x 13 + 5000 x 31
# 1000 x 19 + 2000 x 18 + 5000 x 29
# 1000 x 19 + 2000 x 23 + 5000 x 27
# 1000 x 19 + 2000 x 28 + 5000 x 25
# 1000 x 19 + 2000 x 33 + 5000 x 23
# 1000 x 19 + 2000 x 38 + 5000 x 21
# 1000 x 19 + 2000 x 43 + 5000 x 19
# 1000 x 19 + 2000 x 48 + 5000 x 17
# 1000 x 19 + 2000 x 53 + 5000 x 15
# 1000 x 19 + 2000 x 58 + 5000 x 13
# 1000 x 19 + 2000 x 63 + 5000 x 11
# 1000 x 19 + 2000 x 68 + 5000 x 9
# 1000 x 19 + 2000 x 73 + 5000 x 7
# 1000 x 19 + 2000 x 78 + 5000 x 5
# 1000 x 19 + 2000 x 83 + 5000 x 3
# 1000 x 19 + 2000 x 88 + 5000 x 1
# 1000 x 20 + 2000 x 0 + 5000 x 36
# 1000 x 20 + 2000 x 5 + 5000 x 34
# 1000 x 20 + 2000 x 10 + 5000 x 32
# 1000 x 20 + 2000 x 15 + 5000 x 30
# 1000 x 20 + 2000 x 20 + 5000 x 28
# 1000 x 20 + 2000 x 25 + 5000 x 26
# 1000 x 20 + 2000 x 30 + 5000 x 24
# 1000 x 20 + 2000 x 35 + 5000 x 22
# 1000 x 20 + 2000 x 40 + 5000 x 20
# 1000 x 20 + 2000 x 45 + 5000 x 18
# 1000 x 20 + 2000 x 50 + 5000 x 16
# 1000 x 20 + 2000 x 55 + 5000 x 14
# 1000 x 20 + 2000 x 60 + 5000 x 12
# 1000 x 20 + 2000 x 65 + 5000 x 10
# 1000 x 20 + 2000 x 70 + 5000 x 8
# 1000 x 20 + 2000 x 75 + 5000 x 6
# 1000 x 20 + 2000 x 80 + 5000 x 4
# 1000 x 20 + 2000 x 85 + 5000 x 2
# 1000 x 20 + 2000 x 90 + 5000 x 0
# 1000 x 21 + 2000 x 2 + 5000 x 35
# 1000 x 21 + 2000 x 7 + 5000 x 33
# 1000 x 21 + 2000 x 12 + 5000 x 31
# 1000 x 21 + 2000 x 17 + 5000 x 29
# 1000 x 21 + 2000 x 22 + 5000 x 27
# 1000 x 21 + 2000 x 27 + 5000 x 25
# 1000 x 21 + 2000 x 32 + 5000 x 23
# 1000 x 21 + 2000 x 37 + 5000 x 21
# 1000 x 21 + 2000 x 42 + 5000 x 19
# 1000 x 21 + 2000 x 47 + 5000 x 17
# 1000 x 21 + 2000 x 52 + 5000 x 15
# 1000 x 21 + 2000 x 57 + 5000 x 13
# 1000 x 21 + 2000 x 62 + 5000 x 11
# 1000 x 21 + 2000 x 67 + 5000 x 9
# 1000 x 21 + 2000 x 72 + 5000 x 7
# 1000 x 21 + 2000 x 77 + 5000 x 5
# 1000 x 21 + 2000 x 82 + 5000 x 3
# 1000 x 21 + 2000 x 87 + 5000 x 1
# 1000 x 22 + 2000 x 4 + 5000 x 34
# 1000 x 22 + 2000 x 9 + 5000 x 32
# 1000 x 22 + 2000 x 14 + 5000 x 30
# 1000 x 22 + 2000 x 19 + 5000 x 28
# 1000 x 22 + 2000 x 24 + 5000 x 26
# 1000 x 22 + 2000 x 29 + 5000 x 24
# 1000 x 22 + 2000 x 34 + 5000 x 22
# 1000 x 22 + 2000 x 39 + 5000 x 20
# 1000 x 22 + 2000 x 44 + 5000 x 18
# 1000 x 22 + 2000 x 49 + 5000 x 16
# 1000 x 22 + 2000 x 54 + 5000 x 14
# 1000 x 22 + 2000 x 59 + 5000 x 12
# 1000 x 22 + 2000 x 64 + 5000 x 10
# 1000 x 22 + 2000 x 69 + 5000 x 8
# 1000 x 22 + 2000 x 74 + 5000 x 6
# 1000 x 22 + 2000 x 79 + 5000 x 4
# 1000 x 22 + 2000 x 84 + 5000 x 2
# 1000 x 22 + 2000 x 89 + 5000 x 0
# 1000 x 23 + 2000 x 1 + 5000 x 35
# 1000 x 23 + 2000 x 6 + 5000 x 33
# 1000 x 23 + 2000 x 11 + 5000 x 31
# 1000 x 23 + 2000 x 16 + 5000 x 29
# 1000 x 23 + 2000 x 21 + 5000 x 27
# 1000 x 23 + 2000 x 26 + 5000 x 25
# 1000 x 23 + 2000 x 31 + 5000 x 23
# 1000 x 23 + 2000 x 36 + 5000 x 21
# 1000 x 23 + 2000 x 41 + 5000 x 19
# 1000 x 23 + 2000 x 46 + 5000 x 17
# 1000 x 23 + 2000 x 51 + 5000 x 15
# 1000 x 23 + 2000 x 56 + 5000 x 13
# 1000 x 23 + 2000 x 61 + 5000 x 11
# 1000 x 23 + 2000 x 66 + 5000 x 9
# 1000 x 23 + 2000 x 71 + 5000 x 7
# 1000 x 23 + 2000 x 76 + 5000 x 5
# 1000 x 23 + 2000 x 81 + 5000 x 3
# 1000 x 23 + 2000 x 86 + 5000 x 1
# 1000 x 24 + 2000 x 3 + 5000 x 34
# 1000 x 24 + 2000 x 8 + 5000 x 32
# 1000 x 24 + 2000 x 13 + 5000 x 30
# 1000 x 24 + 2000 x 18 + 5000 x 28
# 1000 x 24 + 2000 x 23 + 5000 x 26
# 1000 x 24 + 2000 x 28 + 5000 x 24
# 1000 x 24 + 2000 x 33 + 5000 x 22
# 1000 x 24 + 2000 x 38 + 5000 x 20
# 1000 x 24 + 2000 x 43 + 5000 x 18
# 1000 x 24 + 2000 x 48 + 5000 x 16
# 1000 x 24 + 2000 x 53 + 5000 x 14
# 1000 x 24 + 2000 x 58 + 5000 x 12
# 1000 x 24 + 2000 x 63 + 5000 x 10
# 1000 x 24 + 2000 x 68 + 5000 x 8
# 1000 x 24 + 2000 x 73 + 5000 x 6
# 1000 x 24 + 2000 x 78 + 5000 x 4
# 1000 x 24 + 2000 x 83 + 5000 x 2
# 1000 x 24 + 2000 x 88 + 5000 x 0
# 1000 x 25 + 2000 x 0 + 5000 x 35
# 1000 x 25 + 2000 x 5 + 5000 x 33
# 1000 x 25 + 2000 x 10 + 5000 x 31
# 1000 x 25 + 2000 x 15 + 5000 x 29
# 1000 x 25 + 2000 x 20 + 5000 x 27
# 1000 x 25 + 2000 x 25 + 5000 x 25
# 1000 x 25 + 2000 x 30 + 5000 x 23
# 1000 x 25 + 2000 x 35 + 5000 x 21
# 1000 x 25 + 2000 x 40 + 5000 x 19
# 1000 x 25 + 2000 x 45 + 5000 x 17
# 1000 x 25 + 2000 x 50 + 5000 x 15
# 1000 x 25 + 2000 x 55 + 5000 x 13
# 1000 x 25 + 2000 x 60 + 5000 x 11
# 1000 x 25 + 2000 x 65 + 5000 x 9
# 1000 x 25 + 2000 x 70 + 5000 x 7
# 1000 x 25 + 2000 x 75 + 5000 x 5
# 1000 x 25 + 2000 x 80 + 5000 x 3
# 1000 x 25 + 2000 x 85 + 5000 x 1
# 1000 x 26 + 2000 x 2 + 5000 x 34
# 1000 x 26 + 2000 x 7 + 5000 x 32
# 1000 x 26 + 2000 x 12 + 5000 x 30
# 1000 x 26 + 2000 x 17 + 5000 x 28
# 1000 x 26 + 2000 x 22 + 5000 x 26
# 1000 x 26 + 2000 x 27 + 5000 x 24
# 1000 x 26 + 2000 x 32 + 5000 x 22
# 1000 x 26 + 2000 x 37 + 5000 x 20
# 1000 x 26 + 2000 x 42 + 5000 x 18
# 1000 x 26 + 2000 x 47 + 5000 x 16
# 1000 x 26 + 2000 x 52 + 5000 x 14
# 1000 x 26 + 2000 x 57 + 5000 x 12
# 1000 x 26 + 2000 x 62 + 5000 x 10
# 1000 x 26 + 2000 x 67 + 5000 x 8
# 1000 x 26 + 2000 x 72 + 5000 x 6
# 1000 x 26 + 2000 x 77 + 5000 x 4
# 1000 x 26 + 2000 x 82 + 5000 x 2
# 1000 x 26 + 2000 x 87 + 5000 x 0
# 1000 x 27 + 2000 x 4 + 5000 x 33
# 1000 x 27 + 2000 x 9 + 5000 x 31
# 1000 x 27 + 2000 x 14 + 5000 x 29
# 1000 x 27 + 2000 x 19 + 5000 x 27
# 1000 x 27 + 2000 x 24 + 5000 x 25
# 1000 x 27 + 2000 x 29 + 5000 x 23
# 1000 x 27 + 2000 x 34 + 5000 x 21
# 1000 x 27 + 2000 x 39 + 5000 x 19
# 1000 x 27 + 2000 x 44 + 5000 x 17
# 1000 x 27 + 2000 x 49 + 5000 x 15
# 1000 x 27 + 2000 x 54 + 5000 x 13
# 1000 x 27 + 2000 x 59 + 5000 x 11
# 1000 x 27 + 2000 x 64 + 5000 x 9
# 1000 x 27 + 2000 x 69 + 5000 x 7
# 1000 x 27 + 2000 x 74 + 5000 x 5
# 1000 x 27 + 2000 x 79 + 5000 x 3
# 1000 x 27 + 2000 x 84 + 5000 x 1
# 1000 x 28 + 2000 x 1 + 5000 x 34
# 1000 x 28 + 2000 x 6 + 5000 x 32
# 1000 x 28 + 2000 x 11 + 5000 x 30
# 1000 x 28 + 2000 x 16 + 5000 x 28
# 1000 x 28 + 2000 x 21 + 5000 x 26
# 1000 x 28 + 2000 x 26 + 5000 x 24
# 1000 x 28 + 2000 x 31 + 5000 x 22
# 1000 x 28 + 2000 x 36 + 5000 x 20
# 1000 x 28 + 2000 x 41 + 5000 x 18
# 1000 x 28 + 2000 x 46 + 5000 x 16
# 1000 x 28 + 2000 x 51 + 5000 x 14
# 1000 x 28 + 2000 x 56 + 5000 x 12
# 1000 x 28 + 2000 x 61 + 5000 x 10
# 1000 x 28 + 2000 x 66 + 5000 x 8
# 1000 x 28 + 2000 x 71 + 5000 x 6
# 1000 x 28 + 2000 x 76 + 5000 x 4
# 1000 x 28 + 2000 x 81 + 5000 x 2
# 1000 x 28 + 2000 x 86 + 5000 x 0
# 1000 x 29 + 2000 x 3 + 5000 x 33
# 1000 x 29 + 2000 x 8 + 5000 x 31
# 1000 x 29 + 2000 x 13 + 5000 x 29
# 1000 x 29 + 2000 x 18 + 5000 x 27
# 1000 x 29 + 2000 x 23 + 5000 x 25
# 1000 x 29 + 2000 x 28 + 5000 x 23
# 1000 x 29 + 2000 x 33 + 5000 x 21
# 1000 x 29 + 2000 x 38 + 5000 x 19
# 1000 x 29 + 2000 x 43 + 5000 x 17
# 1000 x 29 + 2000 x 48 + 5000 x 15
# 1000 x 29 + 2000 x 53 + 5000 x 13
# 1000 x 29 + 2000 x 58 + 5000 x 11
# 1000 x 29 + 2000 x 63 + 5000 x 9
# 1000 x 29 + 2000 x 68 + 5000 x 7
# 1000 x 29 + 2000 x 73 + 5000 x 5
# 1000 x 29 + 2000 x 78 + 5000 x 3
# 1000 x 29 + 2000 x 83 + 5000 x 1
# 1000 x 30 + 2000 x 0 + 5000 x 34
# 1000 x 30 + 2000 x 5 + 5000 x 32
# 1000 x 30 + 2000 x 10 + 5000 x 30
# 1000 x 30 + 2000 x 15 + 5000 x 28
# 1000 x 30 + 2000 x 20 + 5000 x 26
# 1000 x 30 + 2000 x 25 + 5000 x 24
# 1000 x 30 + 2000 x 30 + 5000 x 22
# 1000 x 30 + 2000 x 35 + 5000 x 20
# 1000 x 30 + 2000 x 40 + 5000 x 18
# 1000 x 30 + 2000 x 45 + 5000 x 16
# 1000 x 30 + 2000 x 50 + 5000 x 14
# 1000 x 30 + 2000 x 55 + 5000 x 12
# 1000 x 30 + 2000 x 60 + 5000 x 10
# 1000 x 30 + 2000 x 65 + 5000 x 8
# 1000 x 30 + 2000 x 70 + 5000 x 6
# 1000 x 30 + 2000 x 75 + 5000 x 4
# 1000 x 30 + 2000 x 80 + 5000 x 2
# 1000 x 30 + 2000 x 85 + 5000 x 0
# 1000 x 31 + 2000 x 2 + 5000 x 33
# 1000 x 31 + 2000 x 7 + 5000 x 31
# 1000 x 31 + 2000 x 12 + 5000 x 29
# 1000 x 31 + 2000 x 17 + 5000 x 27
# 1000 x 31 + 2000 x 22 + 5000 x 25
# 1000 x 31 + 2000 x 27 + 5000 x 23
# 1000 x 31 + 2000 x 32 + 5000 x 21
# 1000 x 31 + 2000 x 37 + 5000 x 19
# 1000 x 31 + 2000 x 42 + 5000 x 17
# 1000 x 31 + 2000 x 47 + 5000 x 15
# 1000 x 31 + 2000 x 52 + 5000 x 13
# 1000 x 31 + 2000 x 57 + 5000 x 11
# 1000 x 31 + 2000 x 62 + 5000 x 9
# 1000 x 31 + 2000 x 67 + 5000 x 7
# 1000 x 31 + 2000 x 72 + 5000 x 5
# 1000 x 31 + 2000 x 77 + 5000 x 3
# 1000 x 31 + 2000 x 82 + 5000 x 1
# 1000 x 32 + 2000 x 4 + 5000 x 32
# 1000 x 32 + 2000 x 9 + 5000 x 30
# 1000 x 32 + 2000 x 14 + 5000 x 28
# 1000 x 32 + 2000 x 19 + 5000 x 26
# 1000 x 32 + 2000 x 24 + 5000 x 24
# 1000 x 32 + 2000 x 29 + 5000 x 22
# 1000 x 32 + 2000 x 34 + 5000 x 20
# 1000 x 32 + 2000 x 39 + 5000 x 18
# 1000 x 32 + 2000 x 44 + 5000 x 16
# 1000 x 32 + 2000 x 49 + 5000 x 14
# 1000 x 32 + 2000 x 54 + 5000 x 12
# 1000 x 32 + 2000 x 59 + 5000 x 10
# 1000 x 32 + 2000 x 64 + 5000 x 8
# 1000 x 32 + 2000 x 69 + 5000 x 6
# 1000 x 32 + 2000 x 74 + 5000 x 4
# 1000 x 32 + 2000 x 79 + 5000 x 2
# 1000 x 32 + 2000 x 84 + 5000 x 0
# 1000 x 33 + 2000 x 1 + 5000 x 33
# 1000 x 33 + 2000 x 6 + 5000 x 31
# 1000 x 33 + 2000 x 11 + 5000 x 29
# 1000 x 33 + 2000 x 16 + 5000 x 27
# 1000 x 33 + 2000 x 21 + 5000 x 25
# 1000 x 33 + 2000 x 26 + 5000 x 23
# 1000 x 33 + 2000 x 31 + 5000 x 21
# 1000 x 33 + 2000 x 36 + 5000 x 19
# 1000 x 33 + 2000 x 41 + 5000 x 17
# 1000 x 33 + 2000 x 46 + 5000 x 15
# 1000 x 33 + 2000 x 51 + 5000 x 13
# 1000 x 33 + 2000 x 56 + 5000 x 11
# 1000 x 33 + 2000 x 61 + 5000 x 9
# 1000 x 33 + 2000 x 66 + 5000 x 7
# 1000 x 33 + 2000 x 71 + 5000 x 5
# 1000 x 33 + 2000 x 76 + 5000 x 3
# 1000 x 33 + 2000 x 81 + 5000 x 1
# 1000 x 34 + 2000 x 3 + 5000 x 32
# 1000 x 34 + 2000 x 8 + 5000 x 30
# 1000 x 34 + 2000 x 13 + 5000 x 28
# 1000 x 34 + 2000 x 18 + 5000 x 26
# 1000 x 34 + 2000 x 23 + 5000 x 24
# 1000 x 34 + 2000 x 28 + 5000 x 22
# 1000 x 34 + 2000 x 33 + 5000 x 20
# 1000 x 34 + 2000 x 38 + 5000 x 18
# 1000 x 34 + 2000 x 43 + 5000 x 16
# 1000 x 34 + 2000 x 48 + 5000 x 14
# 1000 x 34 + 2000 x 53 + 5000 x 12
# 1000 x 34 + 2000 x 58 + 5000 x 10
# 1000 x 34 + 2000 x 63 + 5000 x 8
# 1000 x 34 + 2000 x 68 + 5000 x 6
# 1000 x 34 + 2000 x 73 + 5000 x 4
# 1000 x 34 + 2000 x 78 + 5000 x 2
# 1000 x 34 + 2000 x 83 + 5000 x 0
# 1000 x 35 + 2000 x 0 + 5000 x 33
# 1000 x 35 + 2000 x 5 + 5000 x 31
# 1000 x 35 + 2000 x 10 + 5000 x 29
# 1000 x 35 + 2000 x 15 + 5000 x 27
# 1000 x 35 + 2000 x 20 + 5000 x 25
# 1000 x 35 + 2000 x 25 + 5000 x 23
# 1000 x 35 + 2000 x 30 + 5000 x 21
# 1000 x 35 + 2000 x 35 + 5000 x 19
# 1000 x 35 + 2000 x 40 + 5000 x 17
# 1000 x 35 + 2000 x 45 + 5000 x 15
# 1000 x 35 + 2000 x 50 + 5000 x 13
# 1000 x 35 + 2000 x 55 + 5000 x 11
# 1000 x 35 + 2000 x 60 + 5000 x 9
# 1000 x 35 + 2000 x 65 + 5000 x 7
# 1000 x 35 + 2000 x 70 + 5000 x 5
# 1000 x 35 + 2000 x 75 + 5000 x 3
# 1000 x 35 + 2000 x 80 + 5000 x 1
# 1000 x 36 + 2000 x 2 + 5000 x 32
# 1000 x 36 + 2000 x 7 + 5000 x 30
# 1000 x 36 + 2000 x 12 + 5000 x 28
# 1000 x 36 + 2000 x 17 + 5000 x 26
# 1000 x 36 + 2000 x 22 + 5000 x 24
# 1000 x 36 + 2000 x 27 + 5000 x 22
# 1000 x 36 + 2000 x 32 + 5000 x 20
# 1000 x 36 + 2000 x 37 + 5000 x 18
# 1000 x 36 + 2000 x 42 + 5000 x 16
# 1000 x 36 + 2000 x 47 + 5000 x 14
# 1000 x 36 + 2000 x 52 + 5000 x 12
# 1000 x 36 + 2000 x 57 + 5000 x 10
# 1000 x 36 + 2000 x 62 + 5000 x 8
# 1000 x 36 + 2000 x 67 + 5000 x 6
# 1000 x 36 + 2000 x 72 + 5000 x 4
# 1000 x 36 + 2000 x 77 + 5000 x 2
# 1000 x 36 + 2000 x 82 + 5000 x 0
# 1000 x 37 + 2000 x 4 + 5000 x 31
# 1000 x 37 + 2000 x 9 + 5000 x 29
# 1000 x 37 + 2000 x 14 + 5000 x 27
# 1000 x 37 + 2000 x 19 + 5000 x 25
# 1000 x 37 + 2000 x 24 + 5000 x 23
# 1000 x 37 + 2000 x 29 + 5000 x 21
# 1000 x 37 + 2000 x 34 + 5000 x 19
# 1000 x 37 + 2000 x 39 + 5000 x 17
# 1000 x 37 + 2000 x 44 + 5000 x 15
# 1000 x 37 + 2000 x 49 + 5000 x 13
# 1000 x 37 + 2000 x 54 + 5000 x 11
# 1000 x 37 + 2000 x 59 + 5000 x 9
# 1000 x 37 + 2000 x 64 + 5000 x 7
# 1000 x 37 + 2000 x 69 + 5000 x 5
# 1000 x 37 + 2000 x 74 + 5000 x 3
# 1000 x 37 + 2000 x 79 + 5000 x 1
# 1000 x 38 + 2000 x 1 + 5000 x 32
# 1000 x 38 + 2000 x 6 + 5000 x 30
# 1000 x 38 + 2000 x 11 + 5000 x 28
# 1000 x 38 + 2000 x 16 + 5000 x 26
# 1000 x 38 + 2000 x 21 + 5000 x 24
# 1000 x 38 + 2000 x 26 + 5000 x 22
# 1000 x 38 + 2000 x 31 + 5000 x 20
# 1000 x 38 + 2000 x 36 + 5000 x 18
# 1000 x 38 + 2000 x 41 + 5000 x 16
# 1000 x 38 + 2000 x 46 + 5000 x 14
# 1000 x 38 + 2000 x 51 + 5000 x 12
# 1000 x 38 + 2000 x 56 + 5000 x 10
# 1000 x 38 + 2000 x 61 + 5000 x 8
# 1000 x 38 + 2000 x 66 + 5000 x 6
# 1000 x 38 + 2000 x 71 + 5000 x 4
# 1000 x 38 + 2000 x 76 + 5000 x 2
# 1000 x 38 + 2000 x 81 + 5000 x 0
# 1000 x 39 + 2000 x 3 + 5000 x 31
# 1000 x 39 + 2000 x 8 + 5000 x 29
# 1000 x 39 + 2000 x 13 + 5000 x 27
# 1000 x 39 + 2000 x 18 + 5000 x 25
# 1000 x 39 + 2000 x 23 + 5000 x 23
# 1000 x 39 + 2000 x 28 + 5000 x 21
# 1000 x 39 + 2000 x 33 + 5000 x 19
# 1000 x 39 + 2000 x 38 + 5000 x 17
# 1000 x 39 + 2000 x 43 + 5000 x 15
# 1000 x 39 + 2000 x 48 + 5000 x 13
# 1000 x 39 + 2000 x 53 + 5000 x 11
# 1000 x 39 + 2000 x 58 + 5000 x 9
# 1000 x 39 + 2000 x 63 + 5000 x 7
# 1000 x 39 + 2000 x 68 + 5000 x 5
# 1000 x 39 + 2000 x 73 + 5000 x 3
# 1000 x 39 + 2000 x 78 + 5000 x 1
# 1000 x 40 + 2000 x 0 + 5000 x 32
# 1000 x 40 + 2000 x 5 + 5000 x 30
# 1000 x 40 + 2000 x 10 + 5000 x 28
# 1000 x 40 + 2000 x 15 + 5000 x 26
# 1000 x 40 + 2000 x 20 + 5000 x 24
# 1000 x 40 + 2000 x 25 + 5000 x 22
# 1000 x 40 + 2000 x 30 + 5000 x 20
# 1000 x 40 + 2000 x 35 + 5000 x 18
# 1000 x 40 + 2000 x 40 + 5000 x 16
# 1000 x 40 + 2000 x 45 + 5000 x 14
# 1000 x 40 + 2000 x 50 + 5000 x 12
# 1000 x 40 + 2000 x 55 + 5000 x 10
# 1000 x 40 + 2000 x 60 + 5000 x 8
# 1000 x 40 + 2000 x 65 + 5000 x 6
# 1000 x 40 + 2000 x 70 + 5000 x 4
# 1000 x 40 + 2000 x 75 + 5000 x 2
# 1000 x 40 + 2000 x 80 + 5000 x 0
# 1000 x 41 + 2000 x 2 + 5000 x 31
# 1000 x 41 + 2000 x 7 + 5000 x 29
# 1000 x 41 + 2000 x 12 + 5000 x 27
# 1000 x 41 + 2000 x 17 + 5000 x 25
# 1000 x 41 + 2000 x 22 + 5000 x 23
# 1000 x 41 + 2000 x 27 + 5000 x 21
# 1000 x 41 + 2000 x 32 + 5000 x 19
# 1000 x 41 + 2000 x 37 + 5000 x 17
# 1000 x 41 + 2000 x 42 + 5000 x 15
# 1000 x 41 + 2000 x 47 + 5000 x 13
# 1000 x 41 + 2000 x 52 + 5000 x 11
# 1000 x 41 + 2000 x 57 + 5000 x 9
# 1000 x 41 + 2000 x 62 + 5000 x 7
# 1000 x 41 + 2000 x 67 + 5000 x 5
# 1000 x 41 + 2000 x 72 + 5000 x 3
# 1000 x 41 + 2000 x 77 + 5000 x 1
# 1000 x 42 + 2000 x 4 + 5000 x 30
# 1000 x 42 + 2000 x 9 + 5000 x 28
# 1000 x 42 + 2000 x 14 + 5000 x 26
# 1000 x 42 + 2000 x 19 + 5000 x 24
# 1000 x 42 + 2000 x 24 + 5000 x 22
# 1000 x 42 + 2000 x 29 + 5000 x 20
# 1000 x 42 + 2000 x 34 + 5000 x 18
# 1000 x 42 + 2000 x 39 + 5000 x 16
# 1000 x 42 + 2000 x 44 + 5000 x 14
# 1000 x 42 + 2000 x 49 + 5000 x 12
# 1000 x 42 + 2000 x 54 + 5000 x 10
# 1000 x 42 + 2000 x 59 + 5000 x 8
# 1000 x 42 + 2000 x 64 + 5000 x 6
# 1000 x 42 + 2000 x 69 + 5000 x 4
# 1000 x 42 + 2000 x 74 + 5000 x 2
# 1000 x 42 + 2000 x 79 + 5000 x 0
# 1000 x 43 + 2000 x 1 + 5000 x 31
# 1000 x 43 + 2000 x 6 + 5000 x 29
# 1000 x 43 + 2000 x 11 + 5000 x 27
# 1000 x 43 + 2000 x 16 + 5000 x 25
# 1000 x 43 + 2000 x 21 + 5000 x 23
# 1000 x 43 + 2000 x 26 + 5000 x 21
# 1000 x 43 + 2000 x 31 + 5000 x 19
# 1000 x 43 + 2000 x 36 + 5000 x 17
# 1000 x 43 + 2000 x 41 + 5000 x 15
# 1000 x 43 + 2000 x 46 + 5000 x 13
# 1000 x 43 + 2000 x 51 + 5000 x 11
# 1000 x 43 + 2000 x 56 + 5000 x 9
# 1000 x 43 + 2000 x 61 + 5000 x 7
# 1000 x 43 + 2000 x 66 + 5000 x 5
# 1000 x 43 + 2000 x 71 + 5000 x 3
# 1000 x 43 + 2000 x 76 + 5000 x 1
# 1000 x 44 + 2000 x 3 + 5000 x 30
# 1000 x 44 + 2000 x 8 + 5000 x 28
# 1000 x 44 + 2000 x 13 + 5000 x 26
# 1000 x 44 + 2000 x 18 + 5000 x 24
# 1000 x 44 + 2000 x 23 + 5000 x 22
# 1000 x 44 + 2000 x 28 + 5000 x 20
# 1000 x 44 + 2000 x 33 + 5000 x 18
# 1000 x 44 + 2000 x 38 + 5000 x 16
# 1000 x 44 + 2000 x 43 + 5000 x 14
# 1000 x 44 + 2000 x 48 + 5000 x 12
# 1000 x 44 + 2000 x 53 + 5000 x 10
# 1000 x 44 + 2000 x 58 + 5000 x 8
# 1000 x 44 + 2000 x 63 + 5000 x 6
# 1000 x 44 + 2000 x 68 + 5000 x 4
# 1000 x 44 + 2000 x 73 + 5000 x 2
# 1000 x 44 + 2000 x 78 + 5000 x 0
# 1000 x 45 + 2000 x 0 + 5000 x 31
# 1000 x 45 + 2000 x 5 + 5000 x 29
# 1000 x 45 + 2000 x 10 + 5000 x 27
# 1000 x 45 + 2000 x 15 + 5000 x 25
# 1000 x 45 + 2000 x 20 + 5000 x 23
# 1000 x 45 + 2000 x 25 + 5000 x 21
# 1000 x 45 + 2000 x 30 + 5000 x 19
# 1000 x 45 + 2000 x 35 + 5000 x 17
# 1000 x 45 + 2000 x 40 + 5000 x 15
# 1000 x 45 + 2000 x 45 + 5000 x 13
# 1000 x 45 + 2000 x 50 + 5000 x 11
# 1000 x 45 + 2000 x 55 + 5000 x 9
# 1000 x 45 + 2000 x 60 + 5000 x 7
# 1000 x 45 + 2000 x 65 + 5000 x 5
# 1000 x 45 + 2000 x 70 + 5000 x 3
# 1000 x 45 + 2000 x 75 + 5000 x 1
# 1000 x 46 + 2000 x 2 + 5000 x 30
# 1000 x 46 + 2000 x 7 + 5000 x 28
# 1000 x 46 + 2000 x 12 + 5000 x 26
# 1000 x 46 + 2000 x 17 + 5000 x 24
# 1000 x 46 + 2000 x 22 + 5000 x 22
# 1000 x 46 + 2000 x 27 + 5000 x 20
# 1000 x 46 + 2000 x 32 + 5000 x 18
# 1000 x 46 + 2000 x 37 + 5000 x 16
# 1000 x 46 + 2000 x 42 + 5000 x 14
# 1000 x 46 + 2000 x 47 + 5000 x 12
# 1000 x 46 + 2000 x 52 + 5000 x 10
# 1000 x 46 + 2000 x 57 + 5000 x 8
# 1000 x 46 + 2000 x 62 + 5000 x 6
# 1000 x 46 + 2000 x 67 + 5000 x 4
# 1000 x 46 + 2000 x 72 + 5000 x 2
# 1000 x 46 + 2000 x 77 + 5000 x 0
# 1000 x 47 + 2000 x 4 + 5000 x 29
# 1000 x 47 + 2000 x 9 + 5000 x 27
# 1000 x 47 + 2000 x 14 + 5000 x 25
# 1000 x 47 + 2000 x 19 + 5000 x 23
# 1000 x 47 + 2000 x 24 + 5000 x 21
# 1000 x 47 + 2000 x 29 + 5000 x 19
# 1000 x 47 + 2000 x 34 + 5000 x 17
# 1000 x 47 + 2000 x 39 + 5000 x 15
# 1000 x 47 + 2000 x 44 + 5000 x 13
# 1000 x 47 + 2000 x 49 + 5000 x 11
# 1000 x 47 + 2000 x 54 + 5000 x 9
# 1000 x 47 + 2000 x 59 + 5000 x 7
# 1000 x 47 + 2000 x 64 + 5000 x 5
# 1000 x 47 + 2000 x 69 + 5000 x 3
# 1000 x 47 + 2000 x 74 + 5000 x 1
# 1000 x 48 + 2000 x 1 + 5000 x 30
# 1000 x 48 + 2000 x 6 + 5000 x 28
# 1000 x 48 + 2000 x 11 + 5000 x 26
# 1000 x 48 + 2000 x 16 + 5000 x 24
# 1000 x 48 + 2000 x 21 + 5000 x 22
# 1000 x 48 + 2000 x 26 + 5000 x 20
# 1000 x 48 + 2000 x 31 + 5000 x 18
# 1000 x 48 + 2000 x 36 + 5000 x 16
# 1000 x 48 + 2000 x 41 + 5000 x 14
# 1000 x 48 + 2000 x 46 + 5000 x 12
# 1000 x 48 + 2000 x 51 + 5000 x 10
# 1000 x 48 + 2000 x 56 + 5000 x 8
# 1000 x 48 + 2000 x 61 + 5000 x 6
# 1000 x 48 + 2000 x 66 + 5000 x 4
# 1000 x 48 + 2000 x 71 + 5000 x 2
# 1000 x 48 + 2000 x 76 + 5000 x 0
# 1000 x 49 + 2000 x 3 + 5000 x 29
# 1000 x 49 + 2000 x 8 + 5000 x 27
# 1000 x 49 + 2000 x 13 + 5000 x 25
# 1000 x 49 + 2000 x 18 + 5000 x 23
# 1000 x 49 + 2000 x 23 + 5000 x 21
# 1000 x 49 + 2000 x 28 + 5000 x 19
# 1000 x 49 + 2000 x 33 + 5000 x 17
# 1000 x 49 + 2000 x 38 + 5000 x 15
# 1000 x 49 + 2000 x 43 + 5000 x 13
# 1000 x 49 + 2000 x 48 + 5000 x 11
# 1000 x 49 + 2000 x 53 + 5000 x 9
# 1000 x 49 + 2000 x 58 + 5000 x 7
# 1000 x 49 + 2000 x 63 + 5000 x 5
# 1000 x 49 + 2000 x 68 + 5000 x 3
# 1000 x 49 + 2000 x 73 + 5000 x 1
# 1000 x 50 + 2000 x 0 + 5000 x 30
# 1000 x 50 + 2000 x 5 + 5000 x 28
# 1000 x 50 + 2000 x 10 + 5000 x 26
# 1000 x 50 + 2000 x 15 + 5000 x 24
# 1000 x 50 + 2000 x 20 + 5000 x 22
# 1000 x 50 + 2000 x 25 + 5000 x 20
# 1000 x 50 + 2000 x 30 + 5000 x 18
# 1000 x 50 + 2000 x 35 + 5000 x 16
# 1000 x 50 + 2000 x 40 + 5000 x 14
# 1000 x 50 + 2000 x 45 + 5000 x 12
# 1000 x 50 + 2000 x 50 + 5000 x 10
# 1000 x 50 + 2000 x 55 + 5000 x 8
# 1000 x 50 + 2000 x 60 + 5000 x 6
# 1000 x 50 + 2000 x 65 + 5000 x 4
# 1000 x 50 + 2000 x 70 + 5000 x 2
# 1000 x 50 + 2000 x 75 + 5000 x 0
# 1000 x 51 + 2000 x 2 + 5000 x 29
# 1000 x 51 + 2000 x 7 + 5000 x 27
# 1000 x 51 + 2000 x 12 + 5000 x 25
# 1000 x 51 + 2000 x 17 + 5000 x 23
# 1000 x 51 + 2000 x 22 + 5000 x 21
# 1000 x 51 + 2000 x 27 + 5000 x 19
# 1000 x 51 + 2000 x 32 + 5000 x 17
# 1000 x 51 + 2000 x 37 + 5000 x 15
# 1000 x 51 + 2000 x 42 + 5000 x 13
# 1000 x 51 + 2000 x 47 + 5000 x 11
# 1000 x 51 + 2000 x 52 + 5000 x 9
# 1000 x 51 + 2000 x 57 + 5000 x 7
# 1000 x 51 + 2000 x 62 + 5000 x 5
# 1000 x 51 + 2000 x 67 + 5000 x 3
# 1000 x 51 + 2000 x 72 + 5000 x 1
# 1000 x 52 + 2000 x 4 + 5000 x 28
# 1000 x 52 + 2000 x 9 + 5000 x 26
# 1000 x 52 + 2000 x 14 + 5000 x 24
# 1000 x 52 + 2000 x 19 + 5000 x 22
# 1000 x 52 + 2000 x 24 + 5000 x 20
# 1000 x 52 + 2000 x 29 + 5000 x 18
# 1000 x 52 + 2000 x 34 + 5000 x 16
# 1000 x 52 + 2000 x 39 + 5000 x 14
# 1000 x 52 + 2000 x 44 + 5000 x 12
# 1000 x 52 + 2000 x 49 + 5000 x 10
# 1000 x 52 + 2000 x 54 + 5000 x 8
# 1000 x 52 + 2000 x 59 + 5000 x 6
# 1000 x 52 + 2000 x 64 + 5000 x 4
# 1000 x 52 + 2000 x 69 + 5000 x 2
# 1000 x 52 + 2000 x 74 + 5000 x 0
# 1000 x 53 + 2000 x 1 + 5000 x 29
# 1000 x 53 + 2000 x 6 + 5000 x 27
# 1000 x 53 + 2000 x 11 + 5000 x 25
# 1000 x 53 + 2000 x 16 + 5000 x 23
# 1000 x 53 + 2000 x 21 + 5000 x 21
# 1000 x 53 + 2000 x 26 + 5000 x 19
# 1000 x 53 + 2000 x 31 + 5000 x 17
# 1000 x 53 + 2000 x 36 + 5000 x 15
# 1000 x 53 + 2000 x 41 + 5000 x 13
# 1000 x 53 + 2000 x 46 + 5000 x 11
# 1000 x 53 + 2000 x 51 + 5000 x 9
# 1000 x 53 + 2000 x 56 + 5000 x 7
# 1000 x 53 + 2000 x 61 + 5000 x 5
# 1000 x 53 + 2000 x 66 + 5000 x 3
# 1000 x 53 + 2000 x 71 + 5000 x 1
# 1000 x 54 + 2000 x 3 + 5000 x 28
# 1000 x 54 + 2000 x 8 + 5000 x 26
# 1000 x 54 + 2000 x 13 + 5000 x 24
# 1000 x 54 + 2000 x 18 + 5000 x 22
# 1000 x 54 + 2000 x 23 + 5000 x 20
# 1000 x 54 + 2000 x 28 + 5000 x 18
# 1000 x 54 + 2000 x 33 + 5000 x 16
# 1000 x 54 + 2000 x 38 + 5000 x 14
# 1000 x 54 + 2000 x 43 + 5000 x 12
# 1000 x 54 + 2000 x 48 + 5000 x 10
# 1000 x 54 + 2000 x 53 + 5000 x 8
# 1000 x 54 + 2000 x 58 + 5000 x 6
# 1000 x 54 + 2000 x 63 + 5000 x 4
# 1000 x 54 + 2000 x 68 + 5000 x 2
# 1000 x 54 + 2000 x 73 + 5000 x 0
# 1000 x 55 + 2000 x 0 + 5000 x 29
# 1000 x 55 + 2000 x 5 + 5000 x 27
# 1000 x 55 + 2000 x 10 + 5000 x 25
# 1000 x 55 + 2000 x 15 + 5000 x 23
# 1000 x 55 + 2000 x 20 + 5000 x 21
# 1000 x 55 + 2000 x 25 + 5000 x 19
# 1000 x 55 + 2000 x 30 + 5000 x 17
# 1000 x 55 + 2000 x 35 + 5000 x 15
# 1000 x 55 + 2000 x 40 + 5000 x 13
# 1000 x 55 + 2000 x 45 + 5000 x 11
# 1000 x 55 + 2000 x 50 + 5000 x 9
# 1000 x 55 + 2000 x 55 + 5000 x 7
# 1000 x 55 + 2000 x 60 + 5000 x 5
# 1000 x 55 + 2000 x 65 + 5000 x 3
# 1000 x 55 + 2000 x 70 + 5000 x 1
# 1000 x 56 + 2000 x 2 + 5000 x 28
# 1000 x 56 + 2000 x 7 + 5000 x 26
# 1000 x 56 + 2000 x 12 + 5000 x 24
# 1000 x 56 + 2000 x 17 + 5000 x 22
# 1000 x 56 + 2000 x 22 + 5000 x 20
# 1000 x 56 + 2000 x 27 + 5000 x 18
# 1000 x 56 + 2000 x 32 + 5000 x 16
# 1000 x 56 + 2000 x 37 + 5000 x 14
# 1000 x 56 + 2000 x 42 + 5000 x 12
# 1000 x 56 + 2000 x 47 + 5000 x 10
# 1000 x 56 + 2000 x 52 + 5000 x 8
# 1000 x 56 + 2000 x 57 + 5000 x 6
# 1000 x 56 + 2000 x 62 + 5000 x 4
# 1000 x 56 + 2000 x 67 + 5000 x 2
# 1000 x 56 + 2000 x 72 + 5000 x 0
# 1000 x 57 + 2000 x 4 + 5000 x 27
# 1000 x 57 + 2000 x 9 + 5000 x 25
# 1000 x 57 + 2000 x 14 + 5000 x 23
# 1000 x 57 + 2000 x 19 + 5000 x 21
# 1000 x 57 + 2000 x 24 + 5000 x 19
# 1000 x 57 + 2000 x 29 + 5000 x 17
# 1000 x 57 + 2000 x 34 + 5000 x 15
# 1000 x 57 + 2000 x 39 + 5000 x 13
# 1000 x 57 + 2000 x 44 + 5000 x 11
# 1000 x 57 + 2000 x 49 + 5000 x 9
# 1000 x 57 + 2000 x 54 + 5000 x 7
# 1000 x 57 + 2000 x 59 + 5000 x 5
# 1000 x 57 + 2000 x 64 + 5000 x 3
# 1000 x 57 + 2000 x 69 + 5000 x 1
# 1000 x 58 + 2000 x 1 + 5000 x 28
# 1000 x 58 + 2000 x 6 + 5000 x 26
# 1000 x 58 + 2000 x 11 + 5000 x 24
# 1000 x 58 + 2000 x 16 + 5000 x 22
# 1000 x 58 + 2000 x 21 + 5000 x 20
# 1000 x 58 + 2000 x 26 + 5000 x 18
# 1000 x 58 + 2000 x 31 + 5000 x 16
# 1000 x 58 + 2000 x 36 + 5000 x 14
# 1000 x 58 + 2000 x 41 + 5000 x 12
# 1000 x 58 + 2000 x 46 + 5000 x 10
# 1000 x 58 + 2000 x 51 + 5000 x 8
# 1000 x 58 + 2000 x 56 + 5000 x 6
# 1000 x 58 + 2000 x 61 + 5000 x 4
# 1000 x 58 + 2000 x 66 + 5000 x 2
# 1000 x 58 + 2000 x 71 + 5000 x 0
# 1000 x 59 + 2000 x 3 + 5000 x 27
# 1000 x 59 + 2000 x 8 + 5000 x 25
# 1000 x 59 + 2000 x 13 + 5000 x 23
# 1000 x 59 + 2000 x 18 + 5000 x 21
# 1000 x 59 + 2000 x 23 + 5000 x 19
# 1000 x 59 + 2000 x 28 + 5000 x 17
# 1000 x 59 + 2000 x 33 + 5000 x 15
# 1000 x 59 + 2000 x 38 + 5000 x 13
# 1000 x 59 + 2000 x 43 + 5000 x 11
# 1000 x 59 + 2000 x 48 + 5000 x 9
# 1000 x 59 + 2000 x 53 + 5000 x 7
# 1000 x 59 + 2000 x 58 + 5000 x 5
# 1000 x 59 + 2000 x 63 + 5000 x 3
# 1000 x 59 + 2000 x 68 + 5000 x 1
# 1000 x 60 + 2000 x 0 + 5000 x 28
# 1000 x 60 + 2000 x 5 + 5000 x 26
# 1000 x 60 + 2000 x 10 + 5000 x 24
# 1000 x 60 + 2000 x 15 + 5000 x 22
# 1000 x 60 + 2000 x 20 + 5000 x 20
# 1000 x 60 + 2000 x 25 + 5000 x 18
# 1000 x 60 + 2000 x 30 + 5000 x 16
# 1000 x 60 + 2000 x 35 + 5000 x 14
# 1000 x 60 + 2000 x 40 + 5000 x 12
# 1000 x 60 + 2000 x 45 + 5000 x 10
# 1000 x 60 + 2000 x 50 + 5000 x 8
# 1000 x 60 + 2000 x 55 + 5000 x 6
# 1000 x 60 + 2000 x 60 + 5000 x 4
# 1000 x 60 + 2000 x 65 + 5000 x 2
# 1000 x 60 + 2000 x 70 + 5000 x 0
# 1000 x 61 + 2000 x 2 + 5000 x 27
# 1000 x 61 + 2000 x 7 + 5000 x 25
# 1000 x 61 + 2000 x 12 + 5000 x 23
# 1000 x 61 + 2000 x 17 + 5000 x 21
# 1000 x 61 + 2000 x 22 + 5000 x 19
# 1000 x 61 + 2000 x 27 + 5000 x 17
# 1000 x 61 + 2000 x 32 + 5000 x 15
# 1000 x 61 + 2000 x 37 + 5000 x 13
# 1000 x 61 + 2000 x 42 + 5000 x 11
# 1000 x 61 + 2000 x 47 + 5000 x 9
# 1000 x 61 + 2000 x 52 + 5000 x 7
# 1000 x 61 + 2000 x 57 + 5000 x 5
# 1000 x 61 + 2000 x 62 + 5000 x 3
# 1000 x 61 + 2000 x 67 + 5000 x 1
# 1000 x 62 + 2000 x 4 + 5000 x 26
# 1000 x 62 + 2000 x 9 + 5000 x 24
# 1000 x 62 + 2000 x 14 + 5000 x 22
# 1000 x 62 + 2000 x 19 + 5000 x 20
# 1000 x 62 + 2000 x 24 + 5000 x 18
# 1000 x 62 + 2000 x 29 + 5000 x 16
# 1000 x 62 + 2000 x 34 + 5000 x 14
# 1000 x 62 + 2000 x 39 + 5000 x 12
# 1000 x 62 + 2000 x 44 + 5000 x 10
# 1000 x 62 + 2000 x 49 + 5000 x 8
# 1000 x 62 + 2000 x 54 + 5000 x 6
# 1000 x 62 + 2000 x 59 + 5000 x 4
# 1000 x 62 + 2000 x 64 + 5000 x 2
# 1000 x 62 + 2000 x 69 + 5000 x 0
# 1000 x 63 + 2000 x 1 + 5000 x 27
# 1000 x 63 + 2000 x 6 + 5000 x 25
# 1000 x 63 + 2000 x 11 + 5000 x 23
# 1000 x 63 + 2000 x 16 + 5000 x 21
# 1000 x 63 + 2000 x 21 + 5000 x 19
# 1000 x 63 + 2000 x 26 + 5000 x 17
# 1000 x 63 + 2000 x 31 + 5000 x 15
# 1000 x 63 + 2000 x 36 + 5000 x 13
# 1000 x 63 + 2000 x 41 + 5000 x 11
# 1000 x 63 + 2000 x 46 + 5000 x 9
# 1000 x 63 + 2000 x 51 + 5000 x 7
# 1000 x 63 + 2000 x 56 + 5000 x 5
# 1000 x 63 + 2000 x 61 + 5000 x 3
# 1000 x 63 + 2000 x 66 + 5000 x 1
# 1000 x 64 + 2000 x 3 + 5000 x 26
# 1000 x 64 + 2000 x 8 + 5000 x 24
# 1000 x 64 + 2000 x 13 + 5000 x 22
# 1000 x 64 + 2000 x 18 + 5000 x 20
# 1000 x 64 + 2000 x 23 + 5000 x 18
# 1000 x 64 + 2000 x 28 + 5000 x 16
# 1000 x 64 + 2000 x 33 + 5000 x 14
# 1000 x 64 + 2000 x 38 + 5000 x 12
# 1000 x 64 + 2000 x 43 + 5000 x 10
# 1000 x 64 + 2000 x 48 + 5000 x 8
# 1000 x 64 + 2000 x 53 + 5000 x 6
# 1000 x 64 + 2000 x 58 + 5000 x 4
# 1000 x 64 + 2000 x 63 + 5000 x 2
# 1000 x 64 + 2000 x 68 + 5000 x 0
# 1000 x 65 + 2000 x 0 + 5000 x 27
# 1000 x 65 + 2000 x 5 + 5000 x 25
# 1000 x 65 + 2000 x 10 + 5000 x 23
# 1000 x 65 + 2000 x 15 + 5000 x 21
# 1000 x 65 + 2000 x 20 + 5000 x 19
# 1000 x 65 + 2000 x 25 + 5000 x 17
# 1000 x 65 + 2000 x 30 + 5000 x 15
# 1000 x 65 + 2000 x 35 + 5000 x 13
# 1000 x 65 + 2000 x 40 + 5000 x 11
# 1000 x 65 + 2000 x 45 + 5000 x 9
# 1000 x 65 + 2000 x 50 + 5000 x 7
# 1000 x 65 + 2000 x 55 + 5000 x 5
# 1000 x 65 + 2000 x 60 + 5000 x 3
# 1000 x 65 + 2000 x 65 + 5000 x 1
# 1000 x 66 + 2000 x 2 + 5000 x 26
# 1000 x 66 + 2000 x 7 + 5000 x 24
# 1000 x 66 + 2000 x 12 + 5000 x 22
# 1000 x 66 + 2000 x 17 + 5000 x 20
# 1000 x 66 + 2000 x 22 + 5000 x 18
# 1000 x 66 + 2000 x 27 + 5000 x 16
# 1000 x 66 + 2000 x 32 + 5000 x 14
# 1000 x 66 + 2000 x 37 + 5000 x 12
# 1000 x 66 + 2000 x 42 + 5000 x 10
# 1000 x 66 + 2000 x 47 + 5000 x 8
# 1000 x 66 + 2000 x 52 + 5000 x 6
# 1000 x 66 + 2000 x 57 + 5000 x 4
# 1000 x 66 + 2000 x 62 + 5000 x 2
# 1000 x 66 + 2000 x 67 + 5000 x 0
# 1000 x 67 + 2000 x 4 + 5000 x 25
# 1000 x 67 + 2000 x 9 + 5000 x 23
# 1000 x 67 + 2000 x 14 + 5000 x 21
# 1000 x 67 + 2000 x 19 + 5000 x 19
# 1000 x 67 + 2000 x 24 + 5000 x 17
# 1000 x 67 + 2000 x 29 + 5000 x 15
# 1000 x 67 + 2000 x 34 + 5000 x 13
# 1000 x 67 + 2000 x 39 + 5000 x 11
# 1000 x 67 + 2000 x 44 + 5000 x 9
# 1000 x 67 + 2000 x 49 + 5000 x 7
# 1000 x 67 + 2000 x 54 + 5000 x 5
# 1000 x 67 + 2000 x 59 + 5000 x 3
# 1000 x 67 + 2000 x 64 + 5000 x 1
# 1000 x 68 + 2000 x 1 + 5000 x 26
# 1000 x 68 + 2000 x 6 + 5000 x 24
# 1000 x 68 + 2000 x 11 + 5000 x 22
# 1000 x 68 + 2000 x 16 + 5000 x 20
# 1000 x 68 + 2000 x 21 + 5000 x 18
# 1000 x 68 + 2000 x 26 + 5000 x 16
# 1000 x 68 + 2000 x 31 + 5000 x 14
# 1000 x 68 + 2000 x 36 + 5000 x 12
# 1000 x 68 + 2000 x 41 + 5000 x 10
# 1000 x 68 + 2000 x 46 + 5000 x 8
# 1000 x 68 + 2000 x 51 + 5000 x 6
# 1000 x 68 + 2000 x 56 + 5000 x 4
# 1000 x 68 + 2000 x 61 + 5000 x 2
# 1000 x 68 + 2000 x 66 + 5000 x 0
# 1000 x 69 + 2000 x 3 + 5000 x 25
# 1000 x 69 + 2000 x 8 + 5000 x 23
# 1000 x 69 + 2000 x 13 + 5000 x 21
# 1000 x 69 + 2000 x 18 + 5000 x 19
# 1000 x 69 + 2000 x 23 + 5000 x 17
# 1000 x 69 + 2000 x 28 + 5000 x 15
# 1000 x 69 + 2000 x 33 + 5000 x 13
# 1000 x 69 + 2000 x 38 + 5000 x 11
# 1000 x 69 + 2000 x 43 + 5000 x 9
# 1000 x 69 + 2000 x 48 + 5000 x 7
# 1000 x 69 + 2000 x 53 + 5000 x 5
# 1000 x 69 + 2000 x 58 + 5000 x 3
# 1000 x 69 + 2000 x 63 + 5000 x 1
# 1000 x 70 + 2000 x 0 + 5000 x 26
# 1000 x 70 + 2000 x 5 + 5000 x 24
# 1000 x 70 + 2000 x 10 + 5000 x 22
# 1000 x 70 + 2000 x 15 + 5000 x 20
# 1000 x 70 + 2000 x 20 + 5000 x 18
# 1000 x 70 + 2000 x 25 + 5000 x 16
# 1000 x 70 + 2000 x 30 + 5000 x 14
# 1000 x 70 + 2000 x 35 + 5000 x 12
# 1000 x 70 + 2000 x 40 + 5000 x 10
# 1000 x 70 + 2000 x 45 + 5000 x 8
# 1000 x 70 + 2000 x 50 + 5000 x 6
# 1000 x 70 + 2000 x 55 + 5000 x 4
# 1000 x 70 + 2000 x 60 + 5000 x 2
# 1000 x 70 + 2000 x 65 + 5000 x 0
# 1000 x 71 + 2000 x 2 + 5000 x 25
# 1000 x 71 + 2000 x 7 + 5000 x 23
# 1000 x 71 + 2000 x 12 + 5000 x 21
# 1000 x 71 + 2000 x 17 + 5000 x 19
# 1000 x 71 + 2000 x 22 + 5000 x 17
# 1000 x 71 + 2000 x 27 + 5000 x 15
# 1000 x 71 + 2000 x 32 + 5000 x 13
# 1000 x 71 + 2000 x 37 + 5000 x 11
# 1000 x 71 + 2000 x 42 + 5000 x 9
# 1000 x 71 + 2000 x 47 + 5000 x 7
# 1000 x 71 + 2000 x 52 + 5000 x 5
# 1000 x 71 + 2000 x 57 + 5000 x 3
# 1000 x 71 + 2000 x 62 + 5000 x 1
# 1000 x 72 + 2000 x 4 + 5000 x 24
# 1000 x 72 + 2000 x 9 + 5000 x 22
# 1000 x 72 + 2000 x 14 + 5000 x 20
# 1000 x 72 + 2000 x 19 + 5000 x 18
# 1000 x 72 + 2000 x 24 + 5000 x 16
# 1000 x 72 + 2000 x 29 + 5000 x 14
# 1000 x 72 + 2000 x 34 + 5000 x 12
# 1000 x 72 + 2000 x 39 + 5000 x 10
# 1000 x 72 + 2000 x 44 + 5000 x 8
# 1000 x 72 + 2000 x 49 + 5000 x 6
# 1000 x 72 + 2000 x 54 + 5000 x 4
# 1000 x 72 + 2000 x 59 + 5000 x 2
# 1000 x 72 + 2000 x 64 + 5000 x 0
# 1000 x 73 + 2000 x 1 + 5000 x 25
# 1000 x 73 + 2000 x 6 + 5000 x 23
# 1000 x 73 + 2000 x 11 + 5000 x 21
# 1000 x 73 + 2000 x 16 + 5000 x 19
# 1000 x 73 + 2000 x 21 + 5000 x 17
# 1000 x 73 + 2000 x 26 + 5000 x 15
# 1000 x 73 + 2000 x 31 + 5000 x 13
# 1000 x 73 + 2000 x 36 + 5000 x 11
# 1000 x 73 + 2000 x 41 + 5000 x 9
# 1000 x 73 + 2000 x 46 + 5000 x 7
# 1000 x 73 + 2000 x 51 + 5000 x 5
# 1000 x 73 + 2000 x 56 + 5000 x 3
# 1000 x 73 + 2000 x 61 + 5000 x 1
# 1000 x 74 + 2000 x 3 + 5000 x 24
# 1000 x 74 + 2000 x 8 + 5000 x 22
# 1000 x 74 + 2000 x 13 + 5000 x 20
# 1000 x 74 + 2000 x 18 + 5000 x 18
# 1000 x 74 + 2000 x 23 + 5000 x 16
# 1000 x 74 + 2000 x 28 + 5000 x 14
# 1000 x 74 + 2000 x 33 + 5000 x 12
# 1000 x 74 + 2000 x 38 + 5000 x 10
# 1000 x 74 + 2000 x 43 + 5000 x 8
# 1000 x 74 + 2000 x 48 + 5000 x 6
# 1000 x 74 + 2000 x 53 + 5000 x 4
# 1000 x 74 + 2000 x 58 + 5000 x 2
# 1000 x 74 + 2000 x 63 + 5000 x 0
# 1000 x 75 + 2000 x 0 + 5000 x 25
# 1000 x 75 + 2000 x 5 + 5000 x 23
# 1000 x 75 + 2000 x 10 + 5000 x 21
# 1000 x 75 + 2000 x 15 + 5000 x 19
# 1000 x 75 + 2000 x 20 + 5000 x 17
# 1000 x 75 + 2000 x 25 + 5000 x 15
# 1000 x 75 + 2000 x 30 + 5000 x 13
# 1000 x 75 + 2000 x 35 + 5000 x 11
# 1000 x 75 + 2000 x 40 + 5000 x 9
# 1000 x 75 + 2000 x 45 + 5000 x 7
# 1000 x 75 + 2000 x 50 + 5000 x 5
# 1000 x 75 + 2000 x 55 + 5000 x 3
# 1000 x 75 + 2000 x 60 + 5000 x 1
# 1000 x 76 + 2000 x 2 + 5000 x 24
# 1000 x 76 + 2000 x 7 + 5000 x 22
# 1000 x 76 + 2000 x 12 + 5000 x 20
# 1000 x 76 + 2000 x 17 + 5000 x 18
# 1000 x 76 + 2000 x 22 + 5000 x 16
# 1000 x 76 + 2000 x 27 + 5000 x 14
# 1000 x 76 + 2000 x 32 + 5000 x 12
# 1000 x 76 + 2000 x 37 + 5000 x 10
# 1000 x 76 + 2000 x 42 + 5000 x 8
# 1000 x 76 + 2000 x 47 + 5000 x 6
# 1000 x 76 + 2000 x 52 + 5000 x 4
# 1000 x 76 + 2000 x 57 + 5000 x 2
# 1000 x 76 + 2000 x 62 + 5000 x 0
# 1000 x 77 + 2000 x 4 + 5000 x 23
# 1000 x 77 + 2000 x 9 + 5000 x 21
# 1000 x 77 + 2000 x 14 + 5000 x 19
# 1000 x 77 + 2000 x 19 + 5000 x 17
# 1000 x 77 + 2000 x 24 + 5000 x 15
# 1000 x 77 + 2000 x 29 + 5000 x 13
# 1000 x 77 + 2000 x 34 + 5000 x 11
# 1000 x 77 + 2000 x 39 + 5000 x 9
# 1000 x 77 + 2000 x 44 + 5000 x 7
# 1000 x 77 + 2000 x 49 + 5000 x 5
# 1000 x 77 + 2000 x 54 + 5000 x 3
# 1000 x 77 + 2000 x 59 + 5000 x 1
# 1000 x 78 + 2000 x 1 + 5000 x 24
# 1000 x 78 + 2000 x 6 + 5000 x 22
# 1000 x 78 + 2000 x 11 + 5000 x 20
# 1000 x 78 + 2000 x 16 + 5000 x 18
# 1000 x 78 + 2000 x 21 + 5000 x 16
# 1000 x 78 + 2000 x 26 + 5000 x 14
# 1000 x 78 + 2000 x 31 + 5000 x 12
# 1000 x 78 + 2000 x 36 + 5000 x 10
# 1000 x 78 + 2000 x 41 + 5000 x 8
# 1000 x 78 + 2000 x 46 + 5000 x 6
# 1000 x 78 + 2000 x 51 + 5000 x 4
# 1000 x 78 + 2000 x 56 + 5000 x 2
# 1000 x 78 + 2000 x 61 + 5000 x 0
# 1000 x 79 + 2000 x 3 + 5000 x 23
# 1000 x 79 + 2000 x 8 + 5000 x 21
# 1000 x 79 + 2000 x 13 + 5000 x 19
# 1000 x 79 + 2000 x 18 + 5000 x 17
# 1000 x 79 + 2000 x 23 + 5000 x 15
# 1000 x 79 + 2000 x 28 + 5000 x 13
# 1000 x 79 + 2000 x 33 + 5000 x 11
# 1000 x 79 + 2000 x 38 + 5000 x 9
# 1000 x 79 + 2000 x 43 + 5000 x 7
# 1000 x 79 + 2000 x 48 + 5000 x 5
# 1000 x 79 + 2000 x 53 + 5000 x 3
# 1000 x 79 + 2000 x 58 + 5000 x 1
# 1000 x 80 + 2000 x 0 + 5000 x 24
# 1000 x 80 + 2000 x 5 + 5000 x 22
# 1000 x 80 + 2000 x 10 + 5000 x 20
# 1000 x 80 + 2000 x 15 + 5000 x 18
# 1000 x 80 + 2000 x 20 + 5000 x 16
# 1000 x 80 + 2000 x 25 + 5000 x 14
# 1000 x 80 + 2000 x 30 + 5000 x 12
# 1000 x 80 + 2000 x 35 + 5000 x 10
# 1000 x 80 + 2000 x 40 + 5000 x 8
# 1000 x 80 + 2000 x 45 + 5000 x 6
# 1000 x 80 + 2000 x 50 + 5000 x 4
# 1000 x 80 + 2000 x 55 + 5000 x 2
# 1000 x 80 + 2000 x 60 + 5000 x 0
# 1000 x 81 + 2000 x 2 + 5000 x 23
# 1000 x 81 + 2000 x 7 + 5000 x 21
# 1000 x 81 + 2000 x 12 + 5000 x 19
# 1000 x 81 + 2000 x 17 + 5000 x 17
# 1000 x 81 + 2000 x 22 + 5000 x 15
# 1000 x 81 + 2000 x 27 + 5000 x 13
# 1000 x 81 + 2000 x 32 + 5000 x 11
# 1000 x 81 + 2000 x 37 + 5000 x 9
# 1000 x 81 + 2000 x 42 + 5000 x 7
# 1000 x 81 + 2000 x 47 + 5000 x 5
# 1000 x 81 + 2000 x 52 + 5000 x 3
# 1000 x 81 + 2000 x 57 + 5000 x 1
# 1000 x 82 + 2000 x 4 + 5000 x 22
# 1000 x 82 + 2000 x 9 + 5000 x 20
# 1000 x 82 + 2000 x 14 + 5000 x 18
# 1000 x 82 + 2000 x 19 + 5000 x 16
# 1000 x 82 + 2000 x 24 + 5000 x 14
# 1000 x 82 + 2000 x 29 + 5000 x 12
# 1000 x 82 + 2000 x 34 + 5000 x 10
# 1000 x 82 + 2000 x 39 + 5000 x 8
# 1000 x 82 + 2000 x 44 + 5000 x 6
# 1000 x 82 + 2000 x 49 + 5000 x 4
# 1000 x 82 + 2000 x 54 + 5000 x 2
# 1000 x 82 + 2000 x 59 + 5000 x 0
# 1000 x 83 + 2000 x 1 + 5000 x 23
# 1000 x 83 + 2000 x 6 + 5000 x 21
# 1000 x 83 + 2000 x 11 + 5000 x 19
# 1000 x 83 + 2000 x 16 + 5000 x 17
# 1000 x 83 + 2000 x 21 + 5000 x 15
# 1000 x 83 + 2000 x 26 + 5000 x 13
# 1000 x 83 + 2000 x 31 + 5000 x 11
# 1000 x 83 + 2000 x 36 + 5000 x 9
# 1000 x 83 + 2000 x 41 + 5000 x 7
# 1000 x 83 + 2000 x 46 + 5000 x 5
# 1000 x 83 + 2000 x 51 + 5000 x 3
# 1000 x 83 + 2000 x 56 + 5000 x 1
# 1000 x 84 + 2000 x 3 + 5000 x 22
# 1000 x 84 + 2000 x 8 + 5000 x 20
# 1000 x 84 + 2000 x 13 + 5000 x 18
# 1000 x 84 + 2000 x 18 + 5000 x 16
# 1000 x 84 + 2000 x 23 + 5000 x 14
# 1000 x 84 + 2000 x 28 + 5000 x 12
# 1000 x 84 + 2000 x 33 + 5000 x 10
# 1000 x 84 + 2000 x 38 + 5000 x 8
# 1000 x 84 + 2000 x 43 + 5000 x 6
# 1000 x 84 + 2000 x 48 + 5000 x 4
# 1000 x 84 + 2000 x 53 + 5000 x 2
# 1000 x 84 + 2000 x 58 + 5000 x 0
# 1000 x 85 + 2000 x 0 + 5000 x 23
# 1000 x 85 + 2000 x 5 + 5000 x 21
# 1000 x 85 + 2000 x 10 + 5000 x 19
# 1000 x 85 + 2000 x 15 + 5000 x 17
# 1000 x 85 + 2000 x 20 + 5000 x 15
# 1000 x 85 + 2000 x 25 + 5000 x 13
# 1000 x 85 + 2000 x 30 + 5000 x 11
# 1000 x 85 + 2000 x 35 + 5000 x 9
# 1000 x 85 + 2000 x 40 + 5000 x 7
# 1000 x 85 + 2000 x 45 + 5000 x 5
# 1000 x 85 + 2000 x 50 + 5000 x 3
# 1000 x 85 + 2000 x 55 + 5000 x 1
# 1000 x 86 + 2000 x 2 + 5000 x 22
# 1000 x 86 + 2000 x 7 + 5000 x 20
# 1000 x 86 + 2000 x 12 + 5000 x 18
# 1000 x 86 + 2000 x 17 + 5000 x 16
# 1000 x 86 + 2000 x 22 + 5000 x 14
# 1000 x 86 + 2000 x 27 + 5000 x 12
# 1000 x 86 + 2000 x 32 + 5000 x 10
# 1000 x 86 + 2000 x 37 + 5000 x 8
# 1000 x 86 + 2000 x 42 + 5000 x 6
# 1000 x 86 + 2000 x 47 + 5000 x 4
# 1000 x 86 + 2000 x 52 + 5000 x 2
# 1000 x 86 + 2000 x 57 + 5000 x 0
# 1000 x 87 + 2000 x 4 + 5000 x 21
# 1000 x 87 + 2000 x 9 + 5000 x 19
# 1000 x 87 + 2000 x 14 + 5000 x 17
# 1000 x 87 + 2000 x 19 + 5000 x 15
# 1000 x 87 + 2000 x 24 + 5000 x 13
# 1000 x 87 + 2000 x 29 + 5000 x 11
# 1000 x 87 + 2000 x 34 + 5000 x 9
# 1000 x 87 + 2000 x 39 + 5000 x 7
# 1000 x 87 + 2000 x 44 + 5000 x 5
# 1000 x 87 + 2000 x 49 + 5000 x 3
# 1000 x 87 + 2000 x 54 + 5000 x 1
# 1000 x 88 + 2000 x 1 + 5000 x 22
# 1000 x 88 + 2000 x 6 + 5000 x 20
# 1000 x 88 + 2000 x 11 + 5000 x 18
# 1000 x 88 + 2000 x 16 + 5000 x 16
# 1000 x 88 + 2000 x 21 + 5000 x 14
# 1000 x 88 + 2000 x 26 + 5000 x 12
# 1000 x 88 + 2000 x 31 + 5000 x 10
# 1000 x 88 + 2000 x 36 + 5000 x 8
# 1000 x 88 + 2000 x 41 + 5000 x 6
# 1000 x 88 + 2000 x 46 + 5000 x 4
# 1000 x 88 + 2000 x 51 + 5000 x 2
# 1000 x 88 + 2000 x 56 + 5000 x 0
# 1000 x 89 + 2000 x 3 + 5000 x 21
# 1000 x 89 + 2000 x 8 + 5000 x 19
# 1000 x 89 + 2000 x 13 + 5000 x 17
# 1000 x 89 + 2000 x 18 + 5000 x 15
# 1000 x 89 + 2000 x 23 + 5000 x 13
# 1000 x 89 + 2000 x 28 + 5000 x 11
# 1000 x 89 + 2000 x 33 + 5000 x 9
# 1000 x 89 + 2000 x 38 + 5000 x 7
# 1000 x 89 + 2000 x 43 + 5000 x 5
# 1000 x 89 + 2000 x 48 + 5000 x 3
# 1000 x 89 + 2000 x 53 + 5000 x 1
# 1000 x 90 + 2000 x 0 + 5000 x 22
# 1000 x 90 + 2000 x 5 + 5000 x 20
# 1000 x 90 + 2000 x 10 + 5000 x 18
# 1000 x 90 + 2000 x 15 + 5000 x 16
# 1000 x 90 + 2000 x 20 + 5000 x 14
# ...
# 1000 x 106 + 2000 x 42 + 5000 x 2
# 1000 x 106 + 2000 x 47 + 5000 x 0
# 1000 x 107 + 2000 x 4 + 5000 x 17
# 1000 x 107 + 2000 x 9 + 5000 x 15
# 1000 x 107 + 2000 x 14 + 5000 x 13
# 1000 x 107 + 2000 x 19 + 5000 x 11
# 1000 x 107 + 2000 x 24 + 5000 x 9
# 1000 x 107 + 2000 x 29 + 5000 x 7
# 1000 x 107 + 2000 x 34 + 5000 x 5
# 1000 x 107 + 2000 x 39 + 5000 x 3
# 1000 x 107 + 2000 x 44 + 5000 x 1
# 1000 x 108 + 2000 x 1 + 5000 x 18
# 1000 x 108 + 2000 x 6 + 5000 x 16
# 1000 x 108 + 2000 x 11 + 5000 x 14
# 1000 x 108 + 2000 x 16 + 5000 x 12
# 1000 x 108 + 2000 x 21 + 5000 x 10
# 1000 x 108 + 2000 x 26 + 5000 x 8
# 1000 x 108 + 2000 x 31 + 5000 x 6
# 1000 x 108 + 2000 x 36 + 5000 x 4
# 1000 x 108 + 2000 x 41 + 5000 x 2
# 1000 x 108 + 2000 x 46 + 5000 x 0
# 1000 x 109 + 2000 x 3 + 5000 x 17
# 1000 x 109 + 2000 x 8 + 5000 x 15
# 1000 x 109 + 2000 x 13 + 5000 x 13
# 1000 x 109 + 2000 x 18 + 5000 x 11
# 1000 x 109 + 2000 x 23 + 5000 x 9
# 1000 x 109 + 2000 x 28 + 5000 x 7
# 1000 x 109 + 2000 x 33 + 5000 x 5
# 1000 x 109 + 2000 x 38 + 5000 x 3
# 1000 x 109 + 2000 x 43 + 5000 x 1
# 1000 x 110 + 2000 x 0 + 5000 x 18
# 1000 x 110 + 2000 x 5 + 5000 x 16
# 1000 x 110 + 2000 x 10 + 5000 x 14
# 1000 x 110 + 2000 x 15 + 5000 x 12
# 1000 x 110 + 2000 x 20 + 5000 x 10
# 1000 x 110 + 2000 x 25 + 5000 x 8
# 1000 x 110 + 2000 x 30 + 5000 x 6
# 1000 x 110 + 2000 x 35 + 5000 x 4
# 1000 x 110 + 2000 x 40 + 5000 x 2
# 1000 x 110 + 2000 x 45 + 5000 x 0
# 1000 x 111 + 2000 x 2 + 5000 x 17
# 1000 x 111 + 2000 x 7 + 5000 x 15
# 1000 x 111 + 2000 x 12 + 5000 x 13
# 1000 x 111 + 2000 x 17 + 5000 x 11
# 1000 x 111 + 2000 x 22 + 5000 x 9
# 1000 x 111 + 2000 x 27 + 5000 x 7
# 1000 x 111 + 2000 x 32 + 5000 x 5
# 1000 x 111 + 2000 x 37 + 5000 x 3
# 1000 x 111 + 2000 x 42 + 5000 x 1
# 1000 x 112 + 2000 x 4 + 5000 x 16
# 1000 x 112 + 2000 x 9 + 5000 x 14
# 1000 x 112 + 2000 x 14 + 5000 x 12
# 1000 x 112 + 2000 x 19 + 5000 x 10
# 1000 x 112 + 2000 x 24 + 5000 x 8
# 1000 x 112 + 2000 x 29 + 5000 x 6
# 1000 x 112 + 2000 x 34 + 5000 x 4
# 1000 x 112 + 2000 x 39 + 5000 x 2
# 1000 x 112 + 2000 x 44 + 5000 x 0
# 1000 x 113 + 2000 x 1 + 5000 x 17
# 1000 x 113 + 2000 x 6 + 5000 x 15
# 1000 x 113 + 2000 x 11 + 5000 x 13
# 1000 x 113 + 2000 x 16 + 5000 x 11
# 1000 x 113 + 2000 x 21 + 5000 x 9
# 1000 x 113 + 2000 x 26 + 5000 x 7
# 1000 x 113 + 2000 x 31 + 5000 x 5
# 1000 x 113 + 2000 x 36 + 5000 x 3
# 1000 x 113 + 2000 x 41 + 5000 x 1
# 1000 x 114 + 2000 x 3 + 5000 x 16
# 1000 x 114 + 2000 x 8 + 5000 x 14
# 1000 x 114 + 2000 x 13 + 5000 x 12
# 1000 x 114 + 2000 x 18 + 5000 x 10
# 1000 x 114 + 2000 x 23 + 5000 x 8
# 1000 x 114 + 2000 x 28 + 5000 x 6
# 1000 x 114 + 2000 x 33 + 5000 x 4
# 1000 x 114 + 2000 x 38 + 5000 x 2
# 1000 x 114 + 2000 x 43 + 5000 x 0
# 1000 x 115 + 2000 x 0 + 5000 x 17
# 1000 x 115 + 2000 x 5 + 5000 x 15
# 1000 x 115 + 2000 x 10 + 5000 x 13
# 1000 x 115 + 2000 x 15 + 5000 x 11
# 1000 x 115 + 2000 x 20 + 5000 x 9
# 1000 x 115 + 2000 x 25 + 5000 x 7
# 1000 x 115 + 2000 x 30 + 5000 x 5
# 1000 x 115 + 2000 x 35 + 5000 x 3
# 1000 x 115 + 2000 x 40 + 5000 x 1
# 1000 x 116 + 2000 x 2 + 5000 x 16
# 1000 x 116 + 2000 x 7 + 5000 x 14
# 1000 x 116 + 2000 x 12 + 5000 x 12
# 1000 x 116 + 2000 x 17 + 5000 x 10
# 1000 x 116 + 2000 x 22 + 5000 x 8
# 1000 x 116 + 2000 x 27 + 5000 x 6
# 1000 x 116 + 2000 x 32 + 5000 x 4
# 1000 x 116 + 2000 x 37 + 5000 x 2
# 1000 x 116 + 2000 x 42 + 5000 x 0
# 1000 x 117 + 2000 x 4 + 5000 x 15
# 1000 x 117 + 2000 x 9 + 5000 x 13
# 1000 x 117 + 2000 x 14 + 5000 x 11
# 1000 x 117 + 2000 x 19 + 5000 x 9
# 1000 x 117 + 2000 x 24 + 5000 x 7
# 1000 x 117 + 2000 x 29 + 5000 x 5
# 1000 x 117 + 2000 x 34 + 5000 x 3
# 1000 x 117 + 2000 x 39 + 5000 x 1
# 1000 x 118 + 2000 x 1 + 5000 x 16
# 1000 x 118 + 2000 x 6 + 5000 x 14
# 1000 x 118 + 2000 x 11 + 5000 x 12
# 1000 x 118 + 2000 x 16 + 5000 x 10
# 1000 x 118 + 2000 x 21 + 5000 x 8
# 1000 x 118 + 2000 x 26 + 5000 x 6
# 1000 x 118 + 2000 x 31 + 5000 x 4
# 1000 x 118 + 2000 x 36 + 5000 x 2
# 1000 x 118 + 2000 x 41 + 5000 x 0
# 1000 x 119 + 2000 x 3 + 5000 x 15
# 1000 x 119 + 2000 x 8 + 5000 x 13
# 1000 x 119 + 2000 x 13 + 5000 x 11
# 1000 x 119 + 2000 x 18 + 5000 x 9
# 1000 x 119 + 2000 x 23 + 5000 x 7
# 1000 x 119 + 2000 x 28 + 5000 x 5
# 1000 x 119 + 2000 x 33 + 5000 x 3
# 1000 x 119 + 2000 x 38 + 5000 x 1
# 1000 x 120 + 2000 x 0 + 5000 x 16
# 1000 x 120 + 2000 x 5 + 5000 x 14
# 1000 x 120 + 2000 x 10 + 5000 x 12
# 1000 x 120 + 2000 x 15 + 5000 x 10
# 1000 x 120 + 2000 x 20 + 5000 x 8
# 1000 x 120 + 2000 x 25 + 5000 x 6
# 1000 x 120 + 2000 x 30 + 5000 x 4
# 1000 x 120 + 2000 x 35 + 5000 x 2
# 1000 x 120 + 2000 x 40 + 5000 x 0
# 1000 x 121 + 2000 x 2 + 5000 x 15
# 1000 x 121 + 2000 x 7 + 5000 x 13
# 1000 x 121 + 2000 x 12 + 5000 x 11
# 1000 x 121 + 2000 x 17 + 5000 x 9
# 1000 x 121 + 2000 x 22 + 5000 x 7
# 1000 x 121 + 2000 x 27 + 5000 x 5
# 1000 x 121 + 2000 x 32 + 5000 x 3
# 1000 x 121 + 2000 x 37 + 5000 x 1
# 1000 x 122 + 2000 x 4 + 5000 x 14
# 1000 x 122 + 2000 x 9 + 5000 x 12
# 1000 x 122 + 2000 x 14 + 5000 x 10
# 1000 x 122 + 2000 x 19 + 5000 x 8
# 1000 x 122 + 2000 x 24 + 5000 x 6
# 1000 x 122 + 2000 x 29 + 5000 x 4
# 1000 x 122 + 2000 x 34 + 5000 x 2
# 1000 x 122 + 2000 x 39 + 5000 x 0
# 1000 x 123 + 2000 x 1 + 5000 x 15
# 1000 x 123 + 2000 x 6 + 5000 x 13
# 1000 x 123 + 2000 x 11 + 5000 x 11
# 1000 x 123 + 2000 x 16 + 5000 x 9
# 1000 x 123 + 2000 x 21 + 5000 x 7
# 1000 x 123 + 2000 x 26 + 5000 x 5
# 1000 x 123 + 2000 x 31 + 5000 x 3
# 1000 x 123 + 2000 x 36 + 5000 x 1
# 1000 x 124 + 2000 x 3 + 5000 x 14
# 1000 x 124 + 2000 x 8 + 5000 x 12
# 1000 x 124 + 2000 x 13 + 5000 x 10
# 1000 x 124 + 2000 x 18 + 5000 x 8
# 1000 x 124 + 2000 x 23 + 5000 x 6
# 1000 x 124 + 2000 x 28 + 5000 x 4
# 1000 x 124 + 2000 x 33 + 5000 x 2
# 1000 x 124 + 2000 x 38 + 5000 x 0
# 1000 x 125 + 2000 x 0 + 5000 x 15
# 1000 x 125 + 2000 x 5 + 5000 x 13
# 1000 x 125 + 2000 x 10 + 5000 x 11
# 1000 x 125 + 2000 x 15 + 5000 x 9
# 1000 x 125 + 2000 x 20 + 5000 x 7
# 1000 x 125 + 2000 x 25 + 5000 x 5
# 1000 x 125 + 2000 x 30 + 5000 x 3
# 1000 x 125 + 2000 x 35 + 5000 x 1
# 1000 x 126 + 2000 x 2 + 5000 x 14
# 1000 x 126 + 2000 x 7 + 5000 x 12
# 1000 x 126 + 2000 x 12 + 5000 x 10
# 1000 x 126 + 2000 x 17 + 5000 x 8
# 1000 x 126 + 2000 x 22 + 5000 x 6
# 1000 x 126 + 2000 x 27 + 5000 x 4
# 1000 x 126 + 2000 x 32 + 5000 x 2
# 1000 x 126 + 2000 x 37 + 5000 x 0
# 1000 x 127 + 2000 x 4 + 5000 x 13
# 1000 x 127 + 2000 x 9 + 5000 x 11
# 1000 x 127 + 2000 x 14 + 5000 x 9
# 1000 x 127 + 2000 x 19 + 5000 x 7
# 1000 x 127 + 2000 x 24 + 5000 x 5
# 1000 x 127 + 2000 x 29 + 5000 x 3
# 1000 x 127 + 2000 x 34 + 5000 x 1
# 1000 x 128 + 2000 x 1 + 5000 x 14
# 1000 x 128 + 2000 x 6 + 5000 x 12
# 1000 x 128 + 2000 x 11 + 5000 x 10
# 1000 x 128 + 2000 x 16 + 5000 x 8
# 1000 x 128 + 2000 x 21 + 5000 x 6
# 1000 x 128 + 2000 x 26 + 5000 x 4
# 1000 x 128 + 2000 x 31 + 5000 x 2
# 1000 x 128 + 2000 x 36 + 5000 x 0
# 1000 x 129 + 2000 x 3 + 5000 x 13
# 1000 x 129 + 2000 x 8 + 5000 x 11
# 1000 x 129 + 2000 x 13 + 5000 x 9
# 1000 x 129 + 2000 x 18 + 5000 x 7
# 1000 x 129 + 2000 x 23 + 5000 x 5
# 1000 x 129 + 2000 x 28 + 5000 x 3
# 1000 x 129 + 2000 x 33 + 5000 x 1
# 1000 x 130 + 2000 x 0 + 5000 x 14
# 1000 x 130 + 2000 x 5 + 5000 x 12
# 1000 x 130 + 2000 x 10 + 5000 x 10
# 1000 x 130 + 2000 x 15 + 5000 x 8
# 1000 x 130 + 2000 x 20 + 5000 x 6
# 1000 x 130 + 2000 x 25 + 5000 x 4
# 1000 x 130 + 2000 x 30 + 5000 x 2
# 1000 x 130 + 2000 x 35 + 5000 x 0
# 1000 x 131 + 2000 x 2 + 5000 x 13
# 1000 x 131 + 2000 x 7 + 5000 x 11
# 1000 x 131 + 2000 x 12 + 5000 x 9
# 1000 x 131 + 2000 x 17 + 5000 x 7
# 1000 x 131 + 2000 x 22 + 5000 x 5
# 1000 x 131 + 2000 x 27 + 5000 x 3
# 1000 x 131 + 2000 x 32 + 5000 x 1
# 1000 x 132 + 2000 x 4 + 5000 x 12
# 1000 x 132 + 2000 x 9 + 5000 x 10
# 1000 x 132 + 2000 x 14 + 5000 x 8
# 1000 x 132 + 2000 x 19 + 5000 x 6
# 1000 x 132 + 2000 x 24 + 5000 x 4
# 1000 x 132 + 2000 x 29 + 5000 x 2
# 1000 x 132 + 2000 x 34 + 5000 x 0
# 1000 x 133 + 2000 x 1 + 5000 x 13
# 1000 x 133 + 2000 x 6 + 5000 x 11
# 1000 x 133 + 2000 x 11 + 5000 x 9
# 1000 x 133 + 2000 x 16 + 5000 x 7
# 1000 x 133 + 2000 x 21 + 5000 x 5
# 1000 x 133 + 2000 x 26 + 5000 x 3
# 1000 x 133 + 2000 x 31 + 5000 x 1
# 1000 x 134 + 2000 x 3 + 5000 x 12
# 1000 x 134 + 2000 x 8 + 5000 x 10
# 1000 x 134 + 2000 x 13 + 5000 x 8
# 1000 x 134 + 2000 x 18 + 5000 x 6
# 1000 x 134 + 2000 x 23 + 5000 x 4
# 1000 x 134 + 2000 x 28 + 5000 x 2
# 1000 x 134 + 2000 x 33 + 5000 x 0
# 1000 x 135 + 2000 x 0 + 5000 x 13
# 1000 x 135 + 2000 x 5 + 5000 x 11
# 1000 x 135 + 2000 x 10 + 5000 x 9
# 1000 x 135 + 2000 x 15 + 5000 x 7
# 1000 x 135 + 2000 x 20 + 5000 x 5
# 1000 x 135 + 2000 x 25 + 5000 x 3
# 1000 x 135 + 2000 x 30 + 5000 x 1
# 1000 x 136 + 2000 x 2 + 5000 x 12
# 1000 x 136 + 2000 x 7 + 5000 x 10
# 1000 x 136 + 2000 x 12 + 5000 x 8
# 1000 x 136 + 2000 x 17 + 5000 x 6
# 1000 x 136 + 2000 x 22 + 5000 x 4
# 1000 x 136 + 2000 x 27 + 5000 x 2
# 1000 x 136 + 2000 x 32 + 5000 x 0
# 1000 x 137 + 2000 x 4 + 5000 x 11
# 1000 x 137 + 2000 x 9 + 5000 x 9
# 1000 x 137 + 2000 x 14 + 5000 x 7
# 1000 x 137 + 2000 x 19 + 5000 x 5
# 1000 x 137 + 2000 x 24 + 5000 x 3
# 1000 x 137 + 2000 x 29 + 5000 x 1
# 1000 x 138 + 2000 x 1 + 5000 x 12
# 1000 x 138 + 2000 x 6 + 5000 x 10
# 1000 x 138 + 2000 x 11 + 5000 x 8
# 1000 x 138 + 2000 x 16 + 5000 x 6
# 1000 x 138 + 2000 x 21 + 5000 x 4
# 1000 x 138 + 2000 x 26 + 5000 x 2
# 1000 x 138 + 2000 x 31 + 5000 x 0
# 1000 x 139 + 2000 x 3 + 5000 x 11
# 1000 x 139 + 2000 x 8 + 5000 x 9
# 1000 x 139 + 2000 x 13 + 5000 x 7
# 1000 x 139 + 2000 x 18 + 5000 x 5
# 1000 x 139 + 2000 x 23 + 5000 x 3
# 1000 x 139 + 2000 x 28 + 5000 x 1
# 1000 x 140 + 2000 x 0 + 5000 x 12
# 1000 x 140 + 2000 x 5 + 5000 x 10
# 1000 x 140 + 2000 x 10 + 5000 x 8
# 1000 x 140 + 2000 x 15 + 5000 x 6
# 1000 x 140 + 2000 x 20 + 5000 x 4
# 1000 x 140 + 2000 x 25 + 5000 x 2
# 1000 x 140 + 2000 x 30 + 5000 x 0
# 1000 x 141 + 2000 x 2 + 5000 x 11
# 1000 x 141 + 2000 x 7 + 5000 x 9
# 1000 x 141 + 2000 x 12 + 5000 x 7
# 1000 x 141 + 2000 x 17 + 5000 x 5
# 1000 x 141 + 2000 x 22 + 5000 x 3
# 1000 x 141 + 2000 x 27 + 5000 x 1
# 1000 x 142 + 2000 x 4 + 5000 x 10
# 1000 x 142 + 2000 x 9 + 5000 x 8
# 1000 x 142 + 2000 x 14 + 5000 x 6
# 1000 x 142 + 2000 x 19 + 5000 x 4
# 1000 x 142 + 2000 x 24 + 5000 x 2
# 1000 x 142 + 2000 x 29 + 5000 x 0
# 1000 x 143 + 2000 x 1 + 5000 x 11
# 1000 x 143 + 2000 x 6 + 5000 x 9
# 1000 x 143 + 2000 x 11 + 5000 x 7
# 1000 x 143 + 2000 x 16 + 5000 x 5
# 1000 x 143 + 2000 x 21 + 5000 x 3
# 1000 x 143 + 2000 x 26 + 5000 x 1
# 1000 x 144 + 2000 x 3 + 5000 x 10
# 1000 x 144 + 2000 x 8 + 5000 x 8
# 1000 x 144 + 2000 x 13 + 5000 x 6
# 1000 x 144 + 2000 x 18 + 5000 x 4
# 1000 x 144 + 2000 x 23 + 5000 x 2
# 1000 x 144 + 2000 x 28 + 5000 x 0
# 1000 x 145 + 2000 x 0 + 5000 x 11
# 1000 x 145 + 2000 x 5 + 5000 x 9
# 1000 x 145 + 2000 x 10 + 5000 x 7
# 1000 x 145 + 2000 x 15 + 5000 x 5
# 1000 x 145 + 2000 x 20 + 5000 x 3
# 1000 x 145 + 2000 x 25 + 5000 x 1
# 1000 x 146 + 2000 x 2 + 5000 x 10
# 1000 x 146 + 2000 x 7 + 5000 x 8
# 1000 x 146 + 2000 x 12 + 5000 x 6
# 1000 x 146 + 2000 x 17 + 5000 x 4
# 1000 x 146 + 2000 x 22 + 5000 x 2
# 1000 x 146 + 2000 x 27 + 5000 x 0
# 1000 x 147 + 2000 x 4 + 5000 x 9
# 1000 x 147 + 2000 x 9 + 5000 x 7
# 1000 x 147 + 2000 x 14 + 5000 x 5
# 1000 x 147 + 2000 x 19 + 5000 x 3
# 1000 x 147 + 2000 x 24 + 5000 x 1
# 1000 x 148 + 2000 x 1 + 5000 x 10
# 1000 x 148 + 2000 x 6 + 5000 x 8
# 1000 x 148 + 2000 x 11 + 5000 x 6
# 1000 x 148 + 2000 x 16 + 5000 x 4
# 1000 x 148 + 2000 x 21 + 5000 x 2
# 1000 x 148 + 2000 x 26 + 5000 x 0
# 1000 x 149 + 2000 x 3 + 5000 x 9
# 1000 x 149 + 2000 x 8 + 5000 x 7
# 1000 x 149 + 2000 x 13 + 5000 x 5
# 1000 x 149 + 2000 x 18 + 5000 x 3
# 1000 x 149 + 2000 x 23 + 5000 x 1
# 1000 x 150 + 2000 x 0 + 5000 x 10
# 1000 x 150 + 2000 x 5 + 5000 x 8
# 1000 x 150 + 2000 x 10 + 5000 x 6
# 1000 x 150 + 2000 x 15 + 5000 x 4
# 1000 x 150 + 2000 x 20 + 5000 x 2
# 1000 x 150 + 2000 x 25 + 5000 x 0
# 1000 x 151 + 2000 x 2 + 5000 x 9
# 1000 x 151 + 2000 x 7 + 5000 x 7
# 1000 x 151 + 2000 x 12 + 5000 x 5
# 1000 x 151 + 2000 x 17 + 5000 x 3
# 1000 x 151 + 2000 x 22 + 5000 x 1
# 1000 x 152 + 2000 x 4 + 5000 x 8
# 1000 x 152 + 2000 x 9 + 5000 x 6
# 1000 x 152 + 2000 x 14 + 5000 x 4
# 1000 x 152 + 2000 x 19 + 5000 x 2
# 1000 x 152 + 2000 x 24 + 5000 x 0
# 1000 x 153 + 2000 x 1 + 5000 x 9
# 1000 x 153 + 2000 x 6 + 5000 x 7
# 1000 x 153 + 2000 x 11 + 5000 x 5
# 1000 x 153 + 2000 x 16 + 5000 x 3
# 1000 x 153 + 2000 x 21 + 5000 x 1
# 1000 x 154 + 2000 x 3 + 5000 x 8
# 1000 x 154 + 2000 x 8 + 5000 x 6
# 1000 x 154 + 2000 x 13 + 5000 x 4
# 1000 x 154 + 2000 x 18 + 5000 x 2
# 1000 x 154 + 2000 x 23 + 5000 x 0
# 1000 x 155 + 2000 x 0 + 5000 x 9
# 1000 x 155 + 2000 x 5 + 5000 x 7
# 1000 x 155 + 2000 x 10 + 5000 x 5
# 1000 x 155 + 2000 x 15 + 5000 x 3
# 1000 x 155 + 2000 x 20 + 5000 x 1
# 1000 x 156 + 2000 x 2 + 5000 x 8
# 1000 x 156 + 2000 x 7 + 5000 x 6
# 1000 x 156 + 2000 x 12 + 5000 x 4
# 1000 x 156 + 2000 x 17 + 5000 x 2
# 1000 x 156 + 2000 x 22 + 5000 x 0
# 1000 x 157 + 2000 x 4 + 5000 x 7
# 1000 x 157 + 2000 x 9 + 5000 x 5
# 1000 x 157 + 2000 x 14 + 5000 x 3
# 1000 x 157 + 2000 x 19 + 5000 x 1
# 1000 x 158 + 2000 x 1 + 5000 x 8
# 1000 x 158 + 2000 x 6 + 5000 x 6
# 1000 x 158 + 2000 x 11 + 5000 x 4
# 1000 x 158 + 2000 x 16 + 5000 x 2
# 1000 x 158 + 2000 x 21 + 5000 x 0
# 1000 x 159 + 2000 x 3 + 5000 x 7
# 1000 x 159 + 2000 x 8 + 5000 x 5
# 1000 x 159 + 2000 x 13 + 5000 x 3
# 1000 x 159 + 2000 x 18 + 5000 x 1
# 1000 x 160 + 2000 x 0 + 5000 x 8
# 1000 x 160 + 2000 x 5 + 5000 x 6
# 1000 x 160 + 2000 x 10 + 5000 x 4
# 1000 x 160 + 2000 x 15 + 5000 x 2
# 1000 x 160 + 2000 x 20 + 5000 x 0
# 1000 x 161 + 2000 x 2 + 5000 x 7
# 1000 x 161 + 2000 x 7 + 5000 x 5
# 1000 x 161 + 2000 x 12 + 5000 x 3
# 1000 x 161 + 2000 x 17 + 5000 x 1
# 1000 x 162 + 2000 x 4 + 5000 x 6
# 1000 x 162 + 2000 x 9 + 5000 x 4
# 1000 x 162 + 2000 x 14 + 5000 x 2
# 1000 x 162 + 2000 x 19 + 5000 x 0
# 1000 x 163 + 2000 x 1 + 5000 x 7
# 1000 x 163 + 2000 x 6 + 5000 x 5
# 1000 x 163 + 2000 x 11 + 5000 x 3
# 1000 x 163 + 2000 x 16 + 5000 x 1
# 1000 x 164 + 2000 x 3 + 5000 x 6
# 1000 x 164 + 2000 x 8 + 5000 x 4
# 1000 x 164 + 2000 x 13 + 5000 x 2
# 1000 x 164 + 2000 x 18 + 5000 x 0
# 1000 x 165 + 2000 x 0 + 5000 x 7
# 1000 x 165 + 2000 x 5 + 5000 x 5
# 1000 x 165 + 2000 x 10 + 5000 x 3
# 1000 x 165 + 2000 x 15 + 5000 x 1
# 1000 x 166 + 2000 x 2 + 5000 x 6
# 1000 x 166 + 2000 x 7 + 5000 x 4
# 1000 x 166 + 2000 x 12 + 5000 x 2
# 1000 x 166 + 2000 x 17 + 5000 x 0
# 1000 x 167 + 2000 x 4 + 5000 x 5
# 1000 x 167 + 2000 x 9 + 5000 x 3
# 1000 x 167 + 2000 x 14 + 5000 x 1
# 1000 x 168 + 2000 x 1 + 5000 x 6
# 1000 x 168 + 2000 x 6 + 5000 x 4
# 1000 x 168 + 2000 x 11 + 5000 x 2
# 1000 x 168 + 2000 x 16 + 5000 x 0
# 1000 x 169 + 2000 x 3 + 5000 x 5
# 1000 x 169 + 2000 x 8 + 5000 x 3
# 1000 x 169 + 2000 x 13 + 5000 x 1
# 1000 x 170 + 2000 x 0 + 5000 x 6
# 1000 x 170 + 2000 x 5 + 5000 x 4
# 1000 x 170 + 2000 x 10 + 5000 x 2
# 1000 x 170 + 2000 x 15 + 5000 x 0
# 1000 x 171 + 2000 x 2 + 5000 x 5
# 1000 x 171 + 2000 x 7 + 5000 x 3
# 1000 x 171 + 2000 x 12 + 5000 x 1
# 1000 x 172 + 2000 x 4 + 5000 x 4
# 1000 x 172 + 2000 x 9 + 5000 x 2
# 1000 x 172 + 2000 x 14 + 5000 x 0
# 1000 x 173 + 2000 x 1 + 5000 x 5
# 1000 x 173 + 2000 x 6 + 5000 x 3
# 1000 x 173 + 2000 x 11 + 5000 x 1
# 1000 x 174 + 2000 x 3 + 5000 x 4
# 1000 x 174 + 2000 x 8 + 5000 x 2
# 1000 x 174 + 2000 x 13 + 5000 x 0
# 1000 x 175 + 2000 x 0 + 5000 x 5
# 1000 x 175 + 2000 x 5 + 5000 x 3
# 1000 x 175 + 2000 x 10 + 5000 x 1
# 1000 x 176 + 2000 x 2 + 5000 x 4
# 1000 x 176 + 2000 x 7 + 5000 x 2
# 1000 x 176 + 2000 x 12 + 5000 x 0
# 1000 x 177 + 2000 x 4 + 5000 x 3
# 1000 x 177 + 2000 x 9 + 5000 x 1
# 1000 x 178 + 2000 x 1 + 5000 x 4
# 1000 x 178 + 2000 x 6 + 5000 x 2
# 1000 x 178 + 2000 x 11 + 5000 x 0
# 1000 x 179 + 2000 x 3 + 5000 x 3
# 1000 x 179 + 2000 x 8 + 5000 x 1
# 1000 x 180 + 2000 x 0 + 5000 x 4
# 1000 x 180 + 2000 x 5 + 5000 x 2
# 1000 x 180 + 2000 x 10 + 5000 x 0
# 1000 x 181 + 2000 x 2 + 5000 x 3
# 1000 x 181 + 2000 x 7 + 5000 x 1
# 1000 x 182 + 2000 x 4 + 5000 x 2
# 1000 x 182 + 2000 x 9 + 5000 x 0
# 1000 x 183 + 2000 x 1 + 5000 x 3
# 1000 x 183 + 2000 x 6 + 5000 x 1
# 1000 x 184 + 2000 x 3 + 5000 x 2
# 1000 x 184 + 2000 x 8 + 5000 x 0
# 1000 x 185 + 2000 x 0 + 5000 x 3
# 1000 x 185 + 2000 x 5 + 5000 x 1
# 1000 x 186 + 2000 x 2 + 5000 x 2
# 1000 x 186 + 2000 x 7 + 5000 x 0
# 1000 x 187 + 2000 x 4 + 5000 x 1
# 1000 x 188 + 2000 x 1 + 5000 x 2
# 1000 x 188 + 2000 x 6 + 5000 x 0
# 1000 x 189 + 2000 x 3 + 5000 x 1
# 1000 x 190 + 2000 x 0 + 5000 x 2
# 1000 x 190 + 2000 x 5 + 5000 x 0
# 1000 x 191 + 2000 x 2 + 5000 x 1
# 1000 x 192 + 2000 x 4 + 5000 x 0
# 1000 x 193 + 2000 x 1 + 5000 x 1
# 1000 x 194 + 2000 x 3 + 5000 x 0
# 1000 x 195 + 2000 x 0 + 5000 x 1
# 1000 x 196 + 2000 x 2 + 5000 x 0
# 1000 x 198 + 2000 x 1 + 5000 x 0
# 1000 x 200 + 2000 x 0 + 5000 x 0

# %% [markdown]
# ### **** Câu 3 đề thi học sinh giỏi thành phố Hà Nội lớp 9 năm 2008 ****
#
# Trong trò chơi đổi số, một cặp số nguyên dương (x, y) có thể đổi lấy một cặp số mới trong có cặp số (x + y, y), (y, x) hoặc (x-y, y) nếu x-y cũng là số nguyên dương.
#
# Cho trước 4 số nguyên dương a, b, c và d. Người chơi cần tìm cách đổi từ cặp số (a, b)
# thành cặp số (c, d).
#
# <b>Nhập từ bàn phím:</b> 4 số nguyên dương a, b, c và d không vượt qua 1000.
#
# <b>Xuất ra màn hình:</b> số k là số lượng số lần đổi số ít nhất từ cặp số (a, b) nhận được cặp số (c, d). Nếu không tìm được cách đổi số thì xuất K = -1.
#
# Ví dụ: Với a= 14, b = 35, c= 28 và d = 21 thi K = 7.
#
# Quá trình đổi số có thể thực hiện như sau:
#
# Từ cặp số (14,35) ta lần lượt đổi thành các cặp sô (35, 14), (21, 14), (7, 14), (14, 7), (21,7), (7,21) và cuối cùng nhân được cặp số (28,21).
