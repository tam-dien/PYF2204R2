# %% [markdown]
# Ứng dụng thư viện Tkinter 3
#
# ### Thiết kế và lập trình cho giao diện sau:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b> Thiết kế giao diện </b>

# %% [markdown]
# <b> Lập trình hoạt động </b>
