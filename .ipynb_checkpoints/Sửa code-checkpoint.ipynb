# %%
from tkinter import *
sc = Tk()
sc.title("Nhập BCTC")
noidung1 = StringVar()
noidung2 = StringVar()
noidung3 = IntVar()
noidung4 = IntVar()
noidung5 = IntVar()
noidung6 = IntVar()
noidung7 = IntVar()
noidung8 = IntVar()
noidung9 = IntVar()
noidung10 = IntVar()
noidung11 = IntVar()
noidung12 = IntVar()
def tinhtoan():
    entry1.config(state='disabled')
    entry2.config(state='disabled')
    dt = entry3.get()
    gt = entry4.get()
    gvhb = entry6.get()
    dtt = dt - gt
    lng = dtt - gvhb
    cpql = entry8.get()
    tnk = entry9.get()
    cpk = entry10.get()
    lnk = tnk - cpk
    lntt = lng - cpql +lnk
    lbsc5.config(text = str(gt))
    lbsc7.config(text = str())
     
lb1 = Label(sc,text = 'Tên Công ty', font = ("Arial", 12, 'bold'),anchor = 'w')
lb2 = Label(sc,text = 'Kỳ nhập', font = ("Arial", 12,'bold'),anchor = 'w')
lb3 = Label(sc,text = 'Doanh thu bán hàng', font = ("Arial", 12),anchor = 'w')
lb4 = Label(sc,text = 'Các khoản giảm trừ doanh thu', font = ("Arial", 12),anchor = 'w')
lb5 = Label(sc,text = 'Doanh thu thuần', font = ("Arial", 12),anchor = 'w')
lb6 = Label(sc,text = 'Giá vốn hàng bán', font = ("Arial", 12),anchor = 'w')
lb7 = Label(sc,text = 'Lợi nhuận gộp', font = ("Arial", 12),anchor = 'w')
lb8 = Label(sc,text = 'Chi phí quản lý doanh nghiệp', font = ("Arial", 12),anchor = 'w')
lb9 = Label(sc,text = 'Thu nhập khác ', font = ("Arial", 12),anchor = 'w')
lb10 = Label(sc,text = 'Chi phí khác ', font = ("Arial", 12),anchor = 'w')
lb11 = Label(sc,text = 'Lợi nhuận khác', font = ("Arial", 12),anchor = 'w')
lb12 = Label(sc,text = 'Lợi nhuận trước thuế ', font = ("Arial", 12),anchor = 'w')
entry1 = Entry(sc, font = ("Arial", 20), textvariable = noidung1)
entry2 = Entry(sc, font = ("Arial", 20), textvariable = noidung2)
entry3 = Entry(sc, font = ("Arial", 20), textvariable = noidung3)
entry4 = Entry(sc, font = ("Arial", 20), textvariable = noidung4)
lbcs5 = Label(sc,text = "", font = ("Arial", 20),state='disabled')
entry6 = Entry(sc, font = ("Arial", 20), textvariable = noidung6)
lbcs7 = Entry(sc,text = "", font = ("Arial", 20),state='disabled')
entry8 = Entry(sc, font = ("Arial", 20), textvariable = noidung8)
entry9 = Entry(sc, font = ("Arial", 20), textvariable = noidung9)
entry10 = Entry(sc, font = ("Arial", 20), textvariable = noidung10)
lbcs11 = Entry(sc, text = "", font = ("Arial", 20),state='disabled')
lbcs12 = Entry(sc, text = "", font = ("Arial", 20),state='disabled')
nuttinh = Button(sc,text = "Tính toán", font = ("Arial",12), relief = "raised", width = 15, command = tinhtoan)
nutsua = Button(sc,text = "Sửa", font = ("Arial",12), width = 15, relief = "raised" )
lb1.grid(column = 1,row = 1,sticky = "we")
lb2.grid(column = 1,row = 2,sticky = "we")
lb3.grid(column = 1,row = 3,sticky = "we")
lb4.grid(column = 1,row = 4,sticky = "we")
lb5.grid(column = 1,row = 5,sticky = "we")
lb6.grid(column = 1,row = 6,sticky = "we")
lb7.grid(column = 1,row = 7,sticky = "we")
lb8.grid(column = 1,row = 8,sticky = "we")
lb9.grid(column = 1,row = 9,sticky = "we")
lb10.grid(column = 1,row = 10,sticky = "we")
lb11.grid(column = 1,row = 11,sticky = "we")
lb12.grid(column = 1,row = 12,sticky = "we")
entry1.grid(column = 2,row = 1,sticky = "we")
entry2.grid(column = 2,row = 2,sticky = "we")
entry3.grid(column = 2,row = 3,sticky = "we")
entry4.grid(column = 2,row = 4,sticky = "we")
lbcs5.grid(column = 2,row = 5,sticky = "we")
entry6.grid(column = 2,row = 6,sticky = "we")
lbcs7.grid(column = 2,row = 7,sticky = "we")
entry8.grid(column = 2,row = 8,sticky = "we")
entry9.grid(column = 2,row = 9,sticky = "we")
entry10.grid(column = 2,row = 10,sticky = "we")
lbcs11.grid(column = 2,row = 11,sticky = "we")
lbcs12.grid(column = 2,row = 12,sticky = "we")
nuttinh.grid(column = 1,row = 13)
nutsua.grid(column = 2, row = 13)


mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\tamdi\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\tamdi\AppData\Local\Temp/ipykernel_5100/1354300669.py", line 22, in tinhtoan
#     dtt = dt - gt
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
